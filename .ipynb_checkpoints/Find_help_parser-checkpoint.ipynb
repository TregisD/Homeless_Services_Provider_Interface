# %%
from bs4 import BeautifulSoup
import csv
import re
import os 
import pandas as pd
import glob

# %%
data = []

# reading html files from folder

#'Riv_Shelter_HTML_Files'is the name for the shelter HTML Files Riverside
#'Riv_Food_Pantry_HTML_Files'is the name for the food pantry HTML Files for Riverside 
#'Riv_Mental_Health_HTML_Files'is the name for the mental health HTML Files for Riverside
#'Downtown_LA_Food_Pantry_HTML_Files' is the name for the food pantry HTML Files for downtown LA
#'Irvine_Mental_Health_HTML_Files' is the name for the mental health HTML Files for Irvine
folder_path = 'Chenzi Food Pantry HTML'

# Loop through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.html'):
        file_path = os.path.join(folder_path, filename)

        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()

        soup = BeautifulSoup(html_content, 'html.parser')


        # Find the <ul> element with class "best-programs"
        ul_element = soup.find('ul', {'class': 'best-programs'})

        # Find all <li> elements within the <ul>
        li_elements = ul_element.find_all('li', {'class': 'search-result card card-v3 program-info'})

        # Loop through the found <li> elements and extract labels and values
        for li_element in li_elements:
            # Use BeautifulSoup to parse the HTML of each li_element
            li_soup = BeautifulSoup(str(li_element), 'html.parser')

            # Find the program heading 
            program_heading_element = li_soup.find('div', {'class': 'card-heading'})
            Service_name = program_heading_element.find('a', {'class': 'activity-log ph-flyout-click cwdc-flyout-click click-cookie'}).text
            print('Service name: ', Service_name)
    
            # Extract program URL
            program_url_element = program_heading_element.find('a', {'class': 'activity-log ph-flyout-click cwdc-flyout-click click-cookie'})
            program_url = program_url_element['href'] if program_url_element else None
            Service_url = "https://www.auntbertha.com/"+program_url
            print('URL: ', Service_url)
            
            is_reviewed = False

            # Reviewed on
            Reviewd_on_element = program_heading_element.find('div', {'class': 'last-reviewed'})
            if Reviewd_on_element:  # Check if the element exists
                Reviewd_on_text = Reviewd_on_element.get_text(strip=True)  # Clean up the text
                match = re.search(r'\d{2}/\d{2}/\d{4}', Reviewd_on_text)
                Reviewd_on = match.group() if match else None
                if Reviewd_on:  # If we found a review date
                    is_reviewed = True  # Set the flag to True
                print("Reviewed on:", Reviewd_on)
            else:
                Reviewd_on = None  # Set to None if not found
                print("No review date found.")
    
            # Access class="program-tags"
            program_tags = li_soup.find('div', {'class': 'program-tags'})

            # Main Services
            main_s = []
            main_service_list = program_tags.find('ul', {'class': 'list-inline'})
            main_service_items = main_service_list.find_all('li')

            for item in main_service_items:
                main_service = item.find('a', {'class': 'loading-on-click activity-log'}).text.strip()
                main_s.append(main_service)

            print("Main Services:", main_s)

            # Try to access the "Other Services" section
            other_service_list = program_tags.find('div', {'class': 'secondary-tags'})
            if other_service_list:
                other_s = []
                other_service_items = other_service_list.find('ul', {'class': 'list-inline'}).find_all('li')

                for item in other_service_items:
                    other_service = item.find('a', {'class': 'loading-on-click activity-log'}).text.strip()
                    other_s.append(other_service)
            else:
                other_s = None

            print("Other Services:", other_s)

            # Access the "Serving" section
            serving_section = program_tags.find('div', {'class': 'attribute-tags'})

            # Initialize a list to store the serving information
            serving_ = []
    
            # Find all the <li> elements within the serving section
            serving_items = serving_section.find_all('li')

            # Iterate through the serving items and extract the text from the <a> elements
            for item in serving_items:
                link = item.find('a', {'class': 'loading-on-click activity-log'})
    
                # Check if the link was found
                if link:  # Only proceed if the link exists
                    serving_text = link.text.strip()
                    serving_.append(serving_text)

            print("Serving:", serving_)

    
            # accessing next-steps-module, extract phone number, location, hours 
    
            next_steps_module = li_soup.find('div', {'class': 'next-steps-module'})

            # Extract phone number
            phone_number_elements = next_steps_module.find_all('span', {'class': 'result-next-step-item'})

            # Also find all 'a' elements with href attributes containing 'tel:'
            tel_link_elements = next_steps_module.find_all('a', href=True)

            phone_number = None  # Initialize phone number as None

            # Extract phone numbers from text-based spans
            for element in phone_number_elements:
                phone_number_text = element.text.strip() if element else None
    
                # Regex to extract digits (handling separators like spaces or hyphens)
                phone_number_matches = re.findall(r'[\d-]+', phone_number_text)
    
                # Join the digits into a single phone number string if matches are found
                if phone_number_matches:
                    phone_number = ''.join(phone_number_matches)
                    break  # Stop once we've found a phone number

            # If no phone number found from text, check the 'tel:' href links
            if not phone_number:
                for element in tel_link_elements:
                    href_value = element['href']
        
                    # Check if the href contains 'tel:' and extract digits
                    if 'tel:' in href_value:
                        phone_number_matches = re.findall(r'[\d-]+', href_value)
                        if phone_number_matches:
                            phone_number = ''.join(phone_number_matches)
                            break  # Stop once we've found a phone number

            # Print the extracted phone number
            if phone_number:
                print("Phone Number:", phone_number)
            else:
                print("No phone number found.")

            # Extract location address
            location_address_element = next_steps_module.find('a', {'class': 'activity-log ph-flyout-click cwdc-flyout-click map-link with-address'})
            location_address = location_address_element.text.strip() if location_address_element else None
            location_address = re.sub(r'\s+', ' ', location_address) if location_address_element else None
            print("Location Address:", location_address)

            # Extract URL
            location_url_map = location_address_element['href'] if location_address_element else None
            print("Location url map:", location_url_map)
            
            hours_info = {
                '24_hour': False,
                'Monday': None,
                'Tuesday': None,
                'Wednesday': None,
                'Thursday': None,
                'Friday': None,
                'Saturday': None,
                'Sunday': None
            }
            
            # Extract hours based on structure
            hours_element = next_steps_module.find('div', {'class': 'office-hours-schedule see-hours-dropdown'})
            if hours_element:
                # Find all the <span> elements within the hours_element
                day_spans = hours_element.find_all('span')

                # Ensure that we have even pairs of day and corresponding hours
                if len(day_spans) % 2 == 0:
                    # Iterate through the spans in pairs (day and its corresponding hours)
                    for i in range(0, len(day_spans), 2):
                        day_span = day_spans[i]          # This is the day (e.g., "Monday:")
                        hours_span = day_spans[i + 1]    # This is the corresponding hours (e.g., "Closed" or time)

                        # Extract the day name and remove the colon
                        day = day_span.text.strip()[:-1]  # Remove the ':' at the end
                        full_day = day.strip()            # Ensure there's no extra space

                        # Check if the day is valid and exists in hours_info
                        if full_day in hours_info:
                            # Check if the corresponding hours span indicates "Closed"
                            if 'Closed' in hours_span.text:
                                hours_info[full_day] = 'Closed'
                            else:
                                # Extract hours for non-closed days
                                hours_info[full_day] = hours_span.text.strip()
                else:
                    print("Unexpected hours format. Ensure that each day has corresponding hours.")

            # Handle 24-hour information if it exists
            else:
                hours_element = next_steps_module.find('span', {'class': 'result-geo-hours'})
                if hours_element:
                    # Get 24-hour text strip
                    hours_text = hours_element.get_text(strip=True)

                    # Assuming the presence of this text means 24-hour operation
                    if '24' in hours_text or '24-hour' in hours_text.lower():
                        hours_info['24_hour'] = True
                    else:
                        print("Unable to determine if the office is 24 hours.")
                else:
                    print("Hours information not available.")

            # Output the result
            print(hours_info)
    
    
            # Loop through the found <li> elements and extract labels and values
            Extra_element = li_element.find('div', {'class': 'panel-wrapper more-info-panel'})
            elig = []
            eligibility_rules_element = Extra_element.find('div', {'class': 'eligibility-rules'})
    
            # Check if eligibility_rules_element is found
            if eligibility_rules_element:
                # Check if eligibility_rules_element contains a list (ul)
                ul_element = eligibility_rules_element.find('ul')
        
                if ul_element:
                    # If it contains a list, extract list items and store them in a flat list
                    eligibility_list = [li.text.strip() for li in ul_element.find_all('li')]
                    elig.extend(eligibility_list)  # Use extend to add elements to the list directly
                    #print("Eligibility:", eligibility_list)
                else:
                    # If it doesn't contain a list, store the text as is
                    eligibility_text = eligibility_rules_element.text.strip()
                    #print("Eligibility:", [eligibility_text])  # Wrap in a list to maintain consistency
                    elig.append(eligibility_text)

            else:
                # Skip if 'eligibility-rules' class is not found
                pass
    
        
            print("Eligibility:", elig)
    
            # Extract Availability
            availability_element = Extra_element.find('strong', {'data-translate': 'Availability'})
            
            if availability_element:
                availability = availability_element.find_next('div', {'class': 'col-md-10'}).text.strip()
            else:
                availability = "Not specified"

            # Extract Description
            description_element = Extra_element.find('strong', {'data-translate': 'Description'})
            description = description_element.find_next('div', {'class': 'col-md-10'}).text.strip()

            # Extract Languages
            languages_element = Extra_element.find('strong', {'data-translate': 'Languages'})
            languages = languages_element.find_next('div', {'class': 'col-md-10'}).text.strip()
            languages_data = [lang.strip() for lang in languages.split(',')]
            
            # Extract Cost
            cost_element = Extra_element.find('strong', string='Cost:')
            
            if cost_element:  # Check if cost_element exists
                cost = cost_element.find_next('div', {'class': 'col-md-10'}).text.strip()
            else:
                cost = "Not specified"  # Default value if cost_element is not found
            
            # Extract Website URLs if they exist, or set them to None
            website_element = Extra_element.find('div', {'data-translation': 'Website'})
            website_url = website_element.find_next('a', {'class': 'activity-log descriptionProgramWebsite'})['href'] if website_element else None

            # Extract Facebook and Twitter URLs if they exist, or set them to None
            facebook_element = Extra_element.find('strong', {'data-translate': 'Facebook'})
            facebook_url = facebook_element.find_next('a', {'class': 'activity-log descriptionProgramFacebook'})['href'] if facebook_element else None

            twitter_element = Extra_element.find('strong', {'data-translate': 'Twitter'})
            twitter_url = twitter_element.find_next('a', {'class': 'activity-log descriptionProgramTwitter'})['href'] if twitter_element else None

            # Extract Coverage Area
            coverage_element = Extra_element.find('strong', {'data-translate': 'Coverage Area'})
            coverage = coverage_element.find_next('div', {'class': 'col-md-10'}).text.strip()
            
            # Initialize latitude and longitude as None by default
            latitude = None
            longitude = None
            zipcode = None

            # Find the element with class "office-hour-address"
            location_element = Extra_element.find('div', {'class': 'office-hours-address _js_address address notranslate'})

            # Check if the element exists and has the required attributes
            if location_element:
                latitude = location_element['data-latitude'] if location_element.has_attr('data-latitude') else None
                longitude = location_element['data-longitude'] if location_element.has_attr('data-longitude') else None
                print("Latitude:", latitude)
                print("Longitude:", longitude)
                
                # Extract all text within location_element
                address_text = location_element.get_text(separator=" ").strip()  # Get all text as a single string

                # Use regular expression to search for the ZIP code pattern anywhere in the text
                zip_matches = re.findall(r'(?<!\d)(\b\d{5}\b)(?!\d)', address_text)
                zipcode = int(zip_matches[-1]) if zip_matches else None
                print("ZIP Code:", zipcode)

            # Print or use the extracted values as needed
            print("Availability:", availability)
            print("Description:", description)
            print("Languages:", languages_data)
            print("Cost:", cost)
            print("Facebook URL:", facebook_url)
            print("Twitter URL:", twitter_url)
            print("Coverage Area:", coverage)

            data.append([
            Service_name,
            Service_url,
            main_s,
            other_s,
            serving_,
            phone_number,
            website_url,
            location_address,
            location_url_map,
            elig,
            availability,
            description,
            languages_data,
            cost,
            is_reviewed,
            facebook_url,
            twitter_url,
            coverage,
            latitude,
            longitude,
            zipcode,
            hours_info['24_hour'],
            hours_info['Monday'],      
            hours_info['Tuesday'],     
            hours_info['Wednesday'],   
            hours_info['Thursday'],   
            hours_info['Friday'],     
            hours_info['Saturday'],  
            hours_info['Sunday']])    
            print("***************************************************************************")
# Out:
# Service name:  St. Mark's Food Cupboard
# URL:  https://www.auntbertha.com//saint-mark%2527s-church--philadelphia-pa--st.-mark%2527s-food-cupboard/6094953357770752?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['food pantry']
# Other Services: ['personal care items', 'navigating the system']
# Serving: ['anyone in need', 'all ages']
# Phone Number: 215-735-1416101
# Location Address: 1625 Locust Street, Philadelphia, PA 19103
# Location url map: https://www.google.com/maps/?q=1625+Locust+Street,+Philadelphia,+PA+19103/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': '9:30 AM - 11:00 AM  EST', 'Wednesday': '9:30 AM - 11:00 AM  EST', 'Thursday': '9:30 AM - 11:00 AM  EST', 'Friday': '9:30 AM - 11:00 AM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program helps people with income at or below 185% of federal poverty guidelines.', 'This program only serves residents of the state of Pennsylvania.,']
# Latitude: 39.9489257
# Longitude: -75.1683325
# ZIP Code: 19103
# Availability: available
# Description: The Food Cupboard provides various services to families and individuals in the community.
#
# This program provides:
#
# - Supplemental food assistance, largely shelf-stable items
# - Household and personal care items
#
# Other services include:
#
# - Referrals to various other social service agencies, as needed
#
# The Food Cupboard operates from Tuesday to Friday from 9:30 a.m. to 11:00 a.m.
# The Food Cupboard is closed Thanksgiving Day and the Friday afterwards, as well as the week between Christmas and New Year's, and the last full week of July.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/saintmarkschurch
# Twitter URL: https://www.twitter.com/@saintmarksphila
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Distribution
# URL:  https://www.auntbertha.com//north10%252C-philadelphia--philadelphia-pa--food-distribution/5743477776973824?postal=19131
# Reviewed on: 12/17/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 267-908-9000
# Location Address: 3890 North 10th Street, Philadelphia, PA 19140
# Location url map: https://www.google.com/maps/?q=3890+North+10th+Street,+Philadelphia,+PA+19140/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': '10:00 AM - 2:00 PM  EST', 'Wednesday': 'Closed', 'Thursday': '10:00 AM - 2:00 PM  EST', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.0116671
# Longitude: -75.1444282
# ZIP Code: 19140
# Availability: available
# Description: North10, Philadelphia's Community Market provides a food pantry consisting of quality food items to households experiencing food insecurity. This program supplies critical nutrition to hungry individuals and families. This program provides:- Food to meet nutritional needsPlease call before visiting since registration may be required at times.
# Languages: ['English', 'Spanish']
# Cost: Free
# Facebook URL: https://www.facebook.com/lenfest.ctr/
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Cupboard
# URL:  https://www.auntbertha.com//cast-your-cares-ministry--philadelphia-pa--food-cupboard/5742059674402816?postal=19131
# Reviewed on: 12/17/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 215-634-7445
# Location Address: 2438 Kensington Avenue, Philadelphia, PA 19125
# Location url map: https://www.google.com/maps/?q=2438+Kensington+Avenue,+Philadelphia,+PA+19125/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': '2:00 PM - 3:00 PM  EST', 'Wednesday': 'Closed', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 39.987082
# Longitude: -75.1307997
# ZIP Code: 19125
# Availability: available
# Description: Cast Your Cares Ministry's Food Cupboard provides groceries for individuals and families in need. People know they can come to Cast Your Cares to receive food and not just a referral.This program provides:- Food to meet basic nutritional needsDue to the COVID-19 pandemic, grocery pickup is by appointment only. Please stop by and sign up to receive an appointment for groceries on Tuesdays between 2-3 pm.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/castyourcares.org/?eid=ARBqPAC4YneTDv0w8HHVBg_EydvfnGW-FW7XBrl4KkBqWWBw1MYk3rIjmLrbE0Y263FffV8Ru-BiGqQO
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//st.-barbara%2527s-roman-catholic-church--philadelphia-pa--food-pantry/4851628329664512?postal=19131
# Reviewed on: 12/13/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 215-473-1044
# Location Address: 5359 Lebanon Avenue, Philadelphia, PA 19131
# Location url map: https://www.google.com/maps/?q=5359+Lebanon+Avenue,+Philadelphia,+PA+19131/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': '12:00 PM - 2:00 PM  EST', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 39.9878915
# Longitude: -75.2314511
# ZIP Code: 19131
# Availability: available
# Description: The food pantry provides quality food items to households experiencing food insecurity. This program supplies critical nutrition to hungry individuals and families. This program provides:- Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/profile.php?id=100083359778002
# Twitter URL: https://www.twitter.com/@SaintBarbPhilly
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Mitzvah Food Program
# URL:  https://www.auntbertha.com//jewish-federation-of-greater-philadelphia--bala-cynwyd-pa--mitzvah-food-program/4950645635284992?postal=19131
# Reviewed on: 12/14/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families', 'with children']
# Phone Number: 215-832-0831
# Location Address: 345 Montgomery Avenue, Bala Cynwyd, PA 19004
# Location url map: https://www.google.com/maps/?q=345+Montgomery+Avenue,+Bala+Cynwyd,+PA+19004/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': 'Closed', 'Thursday': '1:30 PM - 3:30 PM  EST', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.006306
# Longitude: -75.244297
# ZIP Code: 19004
# Availability: available
# Description: The Mitzvah Food Program addresses hunger and malnutrition by providing nutritious food and basic staples in a caring and dignified manner to individuals and families in need. Visitors choose the foods they like from the inventory, rather than receiving a one-size-fits-all package. There are five pantry locations throughout Greater Philadelphia that distribute non-perishable food packages and produce.This program provides:- Nutritious foodClients may visit twice per month.Please check the office notes for your closest locations regarding hours and availability.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/jewishphilly
# Twitter URL: https://www.twitter.com/@JFedinPhilly
# Coverage Area: This program covers residents of the following counties: Berks County, PA, Chester County, PA, Delaware County, PA, Montgomery County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Resource Fair
# URL:  https://www.auntbertha.com//the-simple-way--philadelphia-pa--resource-fair/5846171090944000?postal=19131
# Reviewed on: 12/17/2024
# Main Services: ['food pantry', 'clothing', 'navigating the system']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families', 'limited english']
# Phone Number: 215-423-3598
# Location Address: 3234 Potter Street, Philadelphia, PA 19134
# Location url map: https://www.google.com/maps/?q=3234+Potter+Street,+Philadelphia,+PA+19134/
# {'24_hour': False, 'Monday': '12:30 PM - 2:30 PM  EST', 'Tuesday': '12:30 PM - 2:30 PM  EST', 'Wednesday': 'Closed', 'Thursday': 'Closed', 'Friday': '9:30 AM - 11:30 AM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 39.9978678
# Longitude: -75.11218960000001
# ZIP Code: 19134
# Availability: available
# Description: On the third Wednesday of every month from 10 am to 12 pm, we host a resource fair in partnership with Esperanza Health Center. Located at 3222 H Street, the resource fair offers food, clothing, and other resources. Appointments are not necessary.
#
# In addition, we have a community refrigerator outside located around the corner from 3234 Potter Street on Westmoreland with fresh food available.
#
# Individuals who are interested in receiving updates on our events can text “FOOD” to 866-551-1675 for updates and the latest information about events, timing, and changes, or follow us on Facebook, Instagram, or Twitter.
# Languages: ['English', 'Spanish']
# Cost: Free
# Facebook URL: https://www.facebook.com/theSimpleWay/
# Twitter URL: https://www.twitter.com/@theSimpleWay
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//the-salvation-army-west-philadelphia-corps-community-center--philadelphia-pa--food-pantry/5687414567993344?postal=19131
# Reviewed on: 12/16/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families', 'homeless', 'near homeless', 'low-income']
# Phone Number: 215-825-4601
# Location Address: 5501 Market Street, Philadelphia, PA 19139
# Location url map: https://www.google.com/maps/?q=5501+Market+Street,+Philadelphia,+PA+19139/
# {'24_hour': False, 'Monday': '9:00 AM - 2:00 PM  EST', 'Tuesday': '9:00 AM - 2:00 PM  EST', 'Wednesday': '9:00 AM - 2:00 PM  EST', 'Thursday': '9:00 AM - 2:00 PM  EST', 'Friday': '9:00 AM - 2:00 PM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 39.9610016
# Longitude: -75.2312927
# ZIP Code: 19139
# Availability: available
# Description: The Salvation Army West Philadelphia Corps Community Center Food Pantry provides groceries and food for families and individuals in need.This program provides:- Food to meet basic nutritional needsFood is free, but some locations require appointments. Others are on a walk-in first come first served basis. Call your local Salvation Army office or the 2-1-1 help line to determine which food pantry serves your area.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/SalArmyPhilly
# Twitter URL: https://www.twitter.com/@SalArmyPhilly
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Farm to Families
# URL:  https://www.auntbertha.com//st.-christopher%2527s-foundation-for-children--philadelphia-pa--farm-to-families/5397808157032448?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['food pantry']
# Other Services: ['nutrition education']
# Serving: ['anyone in need', 'all ages', 'individuals', 'families', 'benefit recipients', 'low-income']
# Phone Number: 484-734-0189
# Location Address: 4865 Market Street, Philadelphia, PA 19139
# Location url map: https://www.google.com/maps/?q=4865+Market+Street,+Philadelphia,+PA+19139/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': 'Closed', 'Thursday': '11:00 AM - 3:00 PM  EST', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Must be eligible for SNAP benefits.']
# Latitude: 39.9595901
# Longitude: -75.2175494
# ZIP Code: 19139
# Availability: available
# Description: Each week, Farm to Families supplies North Philadelphia families with boxes of wholesome fresh produce or fruit at a reduced cost. Boxes are packed with delicious seasonal fruits and vegetables, often valued at double the price. Additional fresh items including local eggs, meat, and seafood are also offered at affordable prices.This program provides:- Food to meet basic nutritional needsFarm to Families also provides food and nutrition education, including food budgeting and shopping tips, basic food preparation and cooking skills, and demonstrations and taste tests, aligned with the weekly boxes.Orders are taken one week in advance. SNAP benefits are all accepted for payment. Farm to Families is open to all with no income restrictions.
# Languages: ['English']
# Cost: Reduced Cost
# Facebook URL: https://www.facebook.com/FarmtoFamilies/
# Twitter URL: https://www.twitter.com/@FarmtoFamilies
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//the-house-of-the-good-shepard-food-pantry--philadelphia-pa--food-pantry/6020830977589248?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 267-235-4454
# Location Address: 1716 North 27th Street, Philadelphia, PA 19121
# Location url map: https://www.google.com/maps/?q=1716+North+27th+Street,+Philadelphia,+PA+19121/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': 'Closed', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': '10:00 AM - 12:00 PM  EST', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 39.981957
# Longitude: -75.179011
# ZIP Code: 19121
# Availability: available
# Description: The House of the Good Shepard Food Pantry offers food once a month to households in need. This program provides:- Food boxPlease visit our location for services or call us for more information.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/thehouseofthegoodshepherd/
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Cupboard
# URL:  https://www.auntbertha.com//the-church-of-st.-andrew-%2526-st.-monica--philadelphia-pa--food-cupboard/6520871286734848?postal=19131
# Reviewed on: 11/12/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# No phone number found.
# Location Address: 3600 Baring Street, Philadelphia, PA 19104
# Location url map: https://www.google.com/maps/?q=3600+Baring+Street,+Philadelphia,+PA+19104/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': 'Closed', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': '9:30 AM - 11:00 AM  EST', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 39.960617
# Longitude: -75.1943448
# ZIP Code: 19104
# Availability: available
# Description: The food pantry provides quality food items to households experiencing food insecurity. This program supplies critical nutrition to hungry individuals and families. This program provides:- Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/ssandrewmonica/?rf=117087431642346
# Twitter URL: https://www.twitter.com/@ssAndrewMonica
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//upper-room-missionary-baptist-church--philadelphia-pa--food-pantry/5789625901776896?postal=19131
# Reviewed on: 12/17/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages']
# Phone Number: 267-593-4989
# Location Address: 7236 Ogontz Avenue, Philadelphia, PA 19138
# Location url map: https://www.google.com/maps/?q=7236+Ogontz+Avenue,+Philadelphia,+PA+19138/
# {'24_hour': False, 'Monday': '10:00 AM - 12:00 PM  EST', 'Tuesday': '9:00 AM - 11:00 AM  EST', 'Wednesday': '8:30 AM - 10:00 AM  EST', 'Thursday': '10:00 AM - 12:00 PM  EST', 'Friday': '9:00 AM - 11:00 AM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves anyone in need.']
# Latitude: 40.064768
# Longitude: -75.1550397
# ZIP Code: 19138
# Availability: available
# Description: Upper Room Missionary Baptist Church offers quality food items to households experiencing food insecurity. This program supplies critical nutrition to hungry individuals and families. This program provides:- Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/Upper-Room-Missionary-Baptist-Church-2195510364097911/
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//st.-luke%2527s-episcopal-church-germantown--philadelphia-pa--food-pantry/5946530422849536?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# No phone number found.
# Location Address: 5421 Germantown Avenue, Philadelphia, PA 19144
# Location url map: https://www.google.com/maps/?q=5421+Germantown+Avenue,+Philadelphia,+PA+19144/
# Hours information not available.
# {'24_hour': False, 'Monday': None, 'Tuesday': None, 'Wednesday': None, 'Thursday': None, 'Friday': None, 'Saturday': None, 'Sunday': None}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.0337844
# Longitude: -75.1709773
# ZIP Code: 19144
# Availability: temporarily closed
# Description: St. Barnabas Pantry provides bags of food to individuals and families in St. Luke's community who are in need.Services provided:- Take-away food bags
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/St-Lukes-Church-Germantown-111657445537323/
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Whole Foods Distribution
# URL:  https://www.auntbertha.com//st.-peter%2527s-evangelical-lutheran-church--philadelphia-pa--whole-foods-distribution/4649723083096064?postal=19131
# Reviewed on: 12/13/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# No phone number found.
# Location Address: 2167 74th Avenue, Philadelphia, PA 19138
# Location url map: https://www.google.com/maps/?q=2167+74th+Avenue,+Philadelphia,+PA+19138/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': '10:30 AM - 12:00 PM  EST', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.0676098
# Longitude: -75.1539533
# ZIP Code: 19138
# Availability: available
# Description: St. Peter's offers a twice monthly fresh food distribution to anyone who is in need in the community. Services provided:- Fresh food to meet basic nutritional needs The only information required is a name, number of people in the household, and a phone number.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/StPeterswol/
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Bank
# URL:  https://www.auntbertha.com//eastwick-united-methodist-church--philadelphia-pa--food-bank/5883670159425536?postal=19131
# Reviewed on: 12/17/2024
# Main Services: ['food pantry']
# Other Services: ['clothing']
# Serving: ['anyone in need', 'all ages']
# Phone Number: 215-365-6352
# Location Address: 8325 Lindbergh Boulevard, Philadelphia, PA 19153
# Location url map: https://www.google.com/maps/?q=8325+Lindbergh+Boulevard,+Philadelphia,+PA+19153/
# {'24_hour': False, 'Monday': '10:00 AM - 1:00 PM  EST', 'Tuesday': '10:00 AM - 1:00 PM  EST', 'Wednesday': '10:00 AM - 1:00 PM  EST', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 39.8981827
# Longitude: -75.2524857
# ZIP Code: 19153
# Availability: available
# Description: Our food bank is a three-day per week ministry serving Southwest Philadelphia and some parts of Delaware County with food and clothing distribution. It has an added component of Bible Study for those who wish to participate and serves as an evangelistic outreach witness for the church.Services provided:- Food to meet basic nutritional needs- Clothing distribution
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Distribution
# URL:  https://www.auntbertha.com//circle-of-hope--philadelphia-pa--food-distribution/6326304658030592?postal=19131
# Reviewed on: 12/19/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages']
# Phone Number: 856-320-8230
# Location Address: 29 West Tulpehocken Street, Philadelphia, PA 19144
# Location url map: https://www.google.com/maps/?q=29+West+Tulpehocken+Street,+Philadelphia,+PA+19144/
# Hours information not available.
# {'24_hour': False, 'Monday': None, 'Tuesday': None, 'Wednesday': None, 'Thursday': None, 'Friday': None, 'Saturday': None, 'Sunday': None}
# Eligibility: ['Those program serves those in Philadelphia and South Jersey.']
# Latitude: 40.0415456
# Longitude: -75.181191
# ZIP Code: 19144
# Availability: full
# Description: Circle of Hope offers food distribution through mutual aid, based on what is currently available.This program provides: - Food distributionPlease note that while those in need can generally call to be added to the waitlist, the list is past capacity and Circle of Hope is not currently accepting new requests for food.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/CircleofHopePhillyRegion/
# Twitter URL: https://www.twitter.com/@CircleofHopeNet
# Coverage Area: This program covers residents of the following counties: Camden County, NJ and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//st.-paul-metropolitan-a.m.e.-church--philadelphia-pa--food-pantry/5184746006904832?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 215-365-3330
# Location Address: 8398 Lindbergh Boulevard, Philadelphia, PA 19153
# Location url map: https://www.google.com/maps/?q=8398+Lindbergh+Boulevard,+Philadelphia,+PA+19153/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': 'Closed', 'Thursday': '8:00 AM - 5:00 PM  EST', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 39.8977253
# Longitude: -75.2515019
# ZIP Code: 19153
# Availability: available
# Description: St. Paul Metropolitan A.M.E. Church provides a food pantry for members of their community. The food pantry serves close to 100 families each Thursday.This program provides:- Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//liberty-house-food-pantry--philadelphia-pa--food-pantry/5710052303044608?postal=19131
# Reviewed on: 12/17/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['all ages']
# Phone Number: 267-257-1673
# Location Address: 1701 North Woodstock Street, Philadelphia, PA 19121
# Location url map: https://www.google.com/maps/?q=1701+North+Woodstock+Street,+Philadelphia,+PA+19121/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': '9:30 AM - 1:30 PM  EST', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: []
# Latitude: 39.9803275
# Longitude: -75.1678318
# ZIP Code: 19121
# Availability: available
# Description: Liberty House Food Pantry provides supplemental groceries to individuals and families in need of assistance. This program provides:- Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//grace-community-christian-center--philadelphia-pa--food-pantry/6223467727552512?postal=19131
# Reviewed on: 12/19/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# No phone number found.
# Location Address: 25 West Johnson Street, Philadelphia, PA 19144
# Location url map: https://www.google.com/maps/?q=25+West+Johnson+Street,+Philadelphia,+PA+19144/
# Hours information not available.
# {'24_hour': False, 'Monday': None, 'Tuesday': None, 'Wednesday': None, 'Thursday': None, 'Friday': None, 'Saturday': None, 'Sunday': None}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.045458
# Longitude: -75.182896
# ZIP Code: 19144
# Availability: temporarily closed
# Description: Grace Community Christian Center food pantry provides supplemental groceries to individuals and families in need of assistance in the community. This program provides:- Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/pg/TheGraceBaptistChurchofGermantown/about/?ref=page_internal
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Human Services
# URL:  https://www.auntbertha.com//african-family-health-organization-%2528afaho%2529--philadelphia-pa--human-services/5355967947210752?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['temporary shelter', 'food pantry', 'mental health care', 'navigating the system', 'case management']
# Other Services: None
# Serving: ['all ages', 'immigrants', 'refugees', 'individuals', 'families']
# Phone Number: 215-546-1232
# Location Address: 2420 South 45th Street, Philadelphia, PA 19143
# Location url map: https://www.google.com/maps/?q=2420+South+45th+Street,+Philadelphia,+PA+19143/
# {'24_hour': False, 'Monday': '8:00 AM - 5:00 PM  EST', 'Tuesday': '8:00 AM - 5:00 PM  EST', 'Wednesday': '8:00 AM - 5:00 PM  EST', 'Thursday': '8:00 AM - 5:00 PM  EST', 'Friday': '8:00 AM - 5:00 PM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves African and Caribbean immigrants/refugees.']
# Latitude: 39.9454475
# Longitude: -75.2085961
# ZIP Code: 19143
# Availability: available
# Description: AFAHO’s multi-lingual and bi-cultural case managers assist clients in mitigating the myriad of barriers they face in accessing critical health and social services which play a vital role in their successful integration, improved health, and ability to be self-sufficient. This program provides:- Behavioral health - Domestic violence awareness and support- Housing assistance and monthly food assistance- Elders' programming- Individual case management- Family case management
# Languages: ['Arabic', 'English', 'French', 'Kinyarwanda', 'Swahili', 'Yoruba']
# Cost: Free
# Facebook URL: https://www.facebook.com/The-Salvation-Army-Nampa-Idaho-208522825852957/
# Twitter URL: https://www.twitter.com/@AFAHO
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//crusaders-for-christ-church--philadelphia-pa--food-pantry/5683489540931584?postal=19131
# Reviewed on: 12/16/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['all ages', 'individuals', 'families']
# Phone Number: 215-387-3014
# Location Address: 1201 South 47th Street, Philadelphia, PA 19143
# Location url map: https://www.google.com/maps/?q=1201+South+47th+Street,+Philadelphia,+PA+19143/
# {'24_hour': False, 'Monday': '8:00 AM - 5:00 PM  EST', 'Tuesday': '8:00 AM - 5:00 PM  EST', 'Wednesday': '8:00 AM - 5:00 PM  EST', 'Thursday': '8:00 AM - 5:00 PM  EST', 'Friday': '8:00 AM - 5:00 PM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: []
# Latitude: 39.9448797
# Longitude: -75.2122188
# ZIP Code: 19143
# Availability: available
# Description: Crusaders for Christ Church provides supplemental groceries to individuals and families in need of assistance in our community. This program provides:- Food to meet basic nutritional needsPlease contact this provider to see when the pantry is available.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/MyCFC1/
# Twitter URL: https://www.twitter.com/@CFC_PA1
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//lifeway-baptist-church--philadelphia-pa--food-pantry/6282969634045952?postal=19131
# Reviewed on: 12/19/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 267-767-6791
# Location Address: 9554 Bustleton Avenue, Philadelphia, PA 19115
# Location url map: https://www.google.com/maps/?q=9554+Bustleton+Avenue,+Philadelphia,+PA+19115/
# {'24_hour': False, 'Monday': '8:00 AM - 5:00 PM  EST', 'Tuesday': '8:00 AM - 5:00 PM  EST', 'Wednesday': '8:00 AM - 5:00 PM  EST', 'Thursday': '8:00 AM - 5:00 PM  EST', 'Friday': '8:00 AM - 5:00 PM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.0870202
# Longitude: -75.0361529
# ZIP Code: 19115
# Availability: available
# Description: The food pantry provides quality food items to households experiencing food insecurity. This program supplies critical nutrition to hungry individuals and families. This program provides:- Food to meet basic nutritional needs
# Languages: ['English', 'Russian']
# Cost: Free
# Facebook URL: https://www.facebook.com/lifewayphila/
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Comida con Amor/Food with Love
# URL:  https://www.auntbertha.com//iglesia-cristiana-avivamiento--philadelphia-pa--comida-con-amor-food-with-love/5390458589806592?postal=19131
# No review date found.
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 215-856-3932
# Location Address: 5500 Tabor Avenue, Philadelphia, PA 19120
# Location url map: https://www.google.com/maps/?q=5500+Tabor+Avenue,+Philadelphia,+PA+19120/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': '10:00 AM - 3:00 PM  EST', 'Wednesday': 'Closed', 'Thursday': '10:00 AM - 3:00 PM  EST', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.0367501
# Longitude: -75.1047313
# ZIP Code: 19120
# Availability: available
# Description: Food with Love serves local communities in the Northeast Philadelphia area and is staffed entirely by volunteers. Food with Love/Comida con Amor operates through donations from the business community, individual sponsors, and the Revival Church congregation.This program provides:- Food to meet basic nutritional needs
# Languages: ['English', 'Spanish']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//african-cultural-alliance-of-north-america-inc.-%2528acana%2529--philadelphia-pa--food-pantry/6524353764130816?postal=19131
# Reviewed on: 11/12/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['all ages', 'immigrants', 'refugees', 'individuals', 'families', 'low-income', 'limited english']
# Phone Number: 215-729-8225
# Location Address: 5530 Chester Avenue, Philadelphia, PA 19143
# Location url map: https://www.google.com/maps/?q=5530+Chester+Avenue,+Philadelphia,+PA+19143/
# {'24_hour': False, 'Monday': '10:00 AM - 6:30 PM  EST', 'Tuesday': '10:00 AM - 6:30 PM  EST', 'Wednesday': '10:00 AM - 6:30 PM  EST', 'Thursday': '10:00 AM - 6:30 PM  EST', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves individuals and families experiencing food insecurity.']
# Latitude: 39.938005
# Longitude: -75.2248314
# ZIP Code: 19143
# Availability: available
# Description: ACANA serves as a food bank and distributes food to members of the Southwest and West Philadelphia community. ACANA can also distribute clothing, toys, building materials and other resources received as donations.This program provides:- Food to meet basic nutritional requirements - Other items as availableThis program is distributed very two weeks at ACANA.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/ACANA.Philadelphia
# Twitter URL: https://www.twitter.com/@ACANAevents
# Coverage Area: This program covers residents of the following counties: Prince Georges County, MD and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Feeding Ministry
# URL:  https://www.auntbertha.com//willow-grove-seventh-day-adventist-church--philadelphia-pa--feeding-ministry/5178565305827328?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 215-657-8364
# Location Address: 4355 Paul Street, Philadelphia, PA 19124
# Location url map: https://www.google.com/maps/?q=4355+Paul+Street,+Philadelphia,+PA+19124/
# {'24_hour': False, 'Monday': '9:00 AM - 2:00 PM  EST', 'Tuesday': '9:00 AM - 2:00 PM  EST', 'Wednesday': '9:00 AM - 2:00 PM  EST', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.0116705
# Longitude: -75.0859812
# ZIP Code: 19124
# Availability: available
# Description: Willow Grove Seventh-day Adventist Church engages in outreach each month by feeding those less fortunate out of our sister church’s site. Services include:- Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Montgomery County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Distribution
# URL:  https://www.auntbertha.com//the-salvation-army-of-greater-philadelphia---philadelphia-central-%2528grays-ferry%2529--philadelphia-pa--food-distribution/4734327233183744?postal=19131
# Reviewed on: 12/13/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['all ages', 'low-income']
# Phone Number: 215-825-4601
# Location Address: 3225 Reed Street, Philadelphia, PA 19146
# Location url map: https://www.google.com/maps/?q=3225+Reed+Street,+Philadelphia,+PA+19146/
# {'24_hour': False, 'Monday': '8:00 AM - 5:00 PM  EST', 'Tuesday': '8:00 AM - 5:00 PM  EST', 'Wednesday': '8:00 AM - 5:00 PM  EST', 'Thursday': '8:00 AM - 5:00 PM  EST', 'Friday': '8:00 AM - 5:00 PM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: []
# Latitude: 39.9370679
# Longitude: -75.197445
# ZIP Code: 19146
# Availability: available
# Description: The Salvation Army provides distribution of nutritious food to those in need.This program provides:- Food distributionParticipants must complete an application and bring documentation before receiving services. Please call for food availability, distribution times, and distribution dates.
# Languages: ['English', 'Spanish']
# Cost: Free
# Facebook URL: https://www.facebook.com/pages/category/Charity-Organization/The-Salvation-Army-CentralGrays-Ferry-Corps-100664791779478/
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Senior Box Program (CSFP)
# URL:  https://www.auntbertha.com//the-share-food-program--philadelphia-pa--senior-box-program-%2528csfp%2529/6572776299298816?postal=19131
# Reviewed on: 11/14/2024
# Main Services: ['food delivery', 'food pantry']
# Other Services: None
# Serving: ['seniors', 'all disabilities', 'limited mobility', 'low-income']
# Phone Number: 215-223-2220
# Location Address: None
# Location url map: None
# {'24_hour': False, 'Monday': '8:30 AM - 4:30 PM  EST', 'Tuesday': '6:00 AM - 6:00 PM  EST', 'Wednesday': '6:00 AM - 6:00 PM  EST', 'Thursday': '6:00 AM - 6:00 PM  EST', 'Friday': '6:00 AM - 6:00 PM  EST', 'Saturday': '8:30 AM - 4:30 PM  EST', 'Sunday': 'Closed'}
# Eligibility: ['This program helps people with income at or below 130% of federal poverty guidelines.', 'This program helps people who are older than 59 years old.']
# Availability: waitlist
# Description: The Share Food Program's Senior Box Program (CSFP) provides food to qualifying seniors. Food boxes can be picked up at a distribution site or delivered to home-bound individuals in need.This program provides:- Food to meet basic nutritional needs.This program operates on a waitlist, please fill out the form on their website.
# Languages: ['English', 'Spanish']
# Cost: Free
# Facebook URL: https://www.facebook.com/SHAREFood/
# Twitter URL: https://www.twitter.com/@sharefoodphilly
# Coverage Area: This program covers residents of the following counties: Chester County, PA, Montgomery County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Supportive Services
# URL:  https://www.auntbertha.com//the-attic-youth-center--philadelphia-pa--supportive-services/6051122713985024?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['food pantry', 'meals', 'health education', 'sex education', 'computer or internet access', 'case management', 'one-on-one support', 'support groups', 'more education', 'tutoring', 'skills & training']
# Other Services: None
# Serving: ['young adults', 'teens', 'infectious disease', 'hiv/aids', 'individuals', 'lgbtqia+']
# Phone Number: 215-545-4331
# Location Address: 255 South 16th Street, Philadelphia, PA 19102
# Location url map: https://www.google.com/maps/?q=255+South+16th+Street,+Philadelphia,+PA+19102/
# {'24_hour': False, 'Monday': '10:00 AM - 6:00 PM  EST', 'Tuesday': '10:00 AM - 7:00 PM  EST', 'Wednesday': '10:00 AM - 7:00 PM  EST', 'Thursday': '10:00 AM - 6:00 PM  EST', 'Friday': '10:00 AM - 7:00 PM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program helps people who are 14 to 23 years old.']
# Latitude: 39.9477596
# Longitude: -75.1678542
# ZIP Code: 19102
# Availability: available
# Description: The Attic Youth Center offers Supportive Services to assist LGBTQ youth in building the skills necessary to succeed in school, their jobs or careers, and the community.This program provides:- Meals- Food pantry- Safer sex supplies- One-on-one support- Support groups- Tutoring- Case management- Internship opportunities- Computer and wifi access
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/pages/The-Attic-Youth-Center/101066143279182
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Montgomery County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//oxford-circle-christian-community-development-association-%2528occcda%2529--philadelphia-pa--food-pantry/4675788288688128?postal=19131
# Reviewed on: 12/13/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals']
# Phone Number: 215-288-8504
# Location Address: 6500 Castor Avenue, Philadelphia, PA 19149
# Location url map: https://www.google.com/maps/?q=6500+Castor+Avenue,+Philadelphia,+PA+19149/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': 'Closed', 'Thursday': '10:00 AM - 2:00 PM  EST', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.040975
# Longitude: -75.0763135
# ZIP Code: 19149
# Availability: available
# Description: The Oxford Circle Christian Community Development Association's food pantry provides quality food items to households experiencing food insecurity. This program supplies critical nutrition to hungry individuals and families. This program provides:- Food to meet basic nutritional needsFood pantry times and dates vary per both locations, please call them for more information.
# Languages: ['Chinese', 'English', 'Spanish']
# Cost: Free
# Facebook URL: https://www.facebook.com/occcda/
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Ministry
# URL:  https://www.auntbertha.com//faith-assembly-of-god--philadelphia-pa--food-ministry/5684138886299648?postal=19131
# Reviewed on: 12/16/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 712-432-3900
# Location Address: 1926 Margaret Street, Philadelphia, PA 19124
# Location url map: https://www.google.com/maps/?q=1926+Margaret+Street,+Philadelphia,+PA+19124/
# {'24_hour': False, 'Monday': '11:00 AM - 4:00 PM  EST', 'Tuesday': '11:00 AM - 4:00 PM  EST', 'Wednesday': '11:00 AM - 4:00 PM  EST', 'Thursday': '11:00 AM - 4:00 PM  EST', 'Friday': '11:00 AM - 4:00 PM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone in need can access this program.']
# Latitude: 40.0129458
# Longitude: -75.0777688
# ZIP Code: 19124
# Availability: available
# Description: The Faith Assembly Of God - Food Ministry provides quality food items to households experiencing food insecurity. This program supplies critical nutrition to hungry individuals and families.This program provides:- Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Distribution
# URL:  https://www.auntbertha.com//kitchen-of-love--philadelphia-pa--food-distribution/5067420438626304?postal=19131
# Reviewed on: 12/14/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['all ages', 'individuals', 'families', 'undocumented']
# No phone number found.
# Location Address: 8500 Pickering Avenue, Philadelphia, PA 19150
# Location url map: https://www.google.com/maps/?q=8500+Pickering+Avenue,+Philadelphia,+PA+19150/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': '9:00 AM - 11:00 AM  EST', 'Thursday': '9:00 AM - 11:00 AM  EST', 'Friday': '9:00 AM - 11:00 AM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Must reside in Philadelphia, PA.']
# Latitude: 40.0813989
# Longitude: -75.1746935
# ZIP Code: 19150
# Availability: waitlist
# Description: Kitchen of Love provides Food Distribution to Philadelphia residents in need. Every Thursday canned foods and meat are distributed and every Friday fresh fruits and vegetables are distributed.This program provides:- Food pantryCurrently, they have a waiting list of more than 100 residents, but as they begin to expand, they will begin to pull more residents from the waiting list.
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  KITHS Kitchen and Garden
# URL:  https://www.auntbertha.com//kiths--philadelphia-pa--kiths-kitchen-and-garden/5480325573640192?postal=19131
# Reviewed on: 12/16/2024
# Main Services: ['emergency food', 'food pantry', 'nutrition education', 'navigating the system']
# Other Services: None
# Serving: ['all ages', 'immigrants', 'refugees', 'individuals', 'families', 'asian', 'undocumented']
# Phone Number: 215-278-6222
# Location Address: 4923 Old York Road, Philadelphia, PA 19141
# Location url map: https://www.google.com/maps/?q=4923+Old+York+Road,+Philadelphia,+PA+19141/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': '9:00 AM - 8:00 PM', 'Wednesday': '9:00 AM - 8:00 PM', 'Thursday': '9:00 AM - 8:00 PM', 'Friday': '6:30 PM - 8:00 PM', 'Saturday': '12:00 PM - 6:00 PM', 'Sunday': 'Closed'}
# Eligibility: []
# Latitude: 40.0280731
# Longitude: -75.146067
# ZIP Code: 19141
# Availability: available
# Description: KITHS Kitchen provides a culturally affirming stock pantry, supplied with food items reflective of what Cambodian refugees and Southeast Asians normally consume, such as canned baby corn, rice, seafood-based staples that are reminiscent of cuisines from their native countries (e.g., fish sauce, oyster sauce, etc.).This program provides:- Food distribution- Nutrition education- Information about food access opportunities- Emergency pantryKITHS cannot guarantee services without an appointment. Please call for more information.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/kithsnonprofit/
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//centre-d%2527adoration-chretienne--philadelphia-pa--food-pantry/5555306549346304?postal=19131
# Reviewed on: 12/16/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 215-548-3788
# Location Address: 4520 Benner Street, Philadelphia, PA 19135
# Location url map: https://www.google.com/maps/?q=4520+Benner+Street,+Philadelphia,+PA+19135/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': '7:30 PM - 9:00 PM  EST', 'Wednesday': 'Closed', 'Thursday': '7:30 PM - 9:00 PM  EST', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves anyone in need.']
# Latitude: 40.01987
# Longitude: -75.05921099999999
# ZIP Code: 19135
# Availability: available
# ...
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Commodity Supplemental Food Program(CSFP)/Senior
# URL:  https://www.auntbertha.com//philabundance--philadelphia-pa--commodity-supplemental-food-program%2528csfp%2529-senior/5692243664961536?postal=19131
# Reviewed on: 12/16/2024
# Main Services: ['food pantry']
# Other Services: ['food pantry']
# Serving: ['seniors', 'individuals', 'low-income']
# Phone Number: 215-339-09002152
# Location Address: 302 West Berks Street, Philadelphia, PA 19122
# Location url map: https://www.google.com/maps/?q=302+West+Berks+Street,+Philadelphia,+PA+19122/
# {'24_hour': False, 'Monday': '8:30 AM - 4:30 PM  EST', 'Tuesday': '8:30 AM - 4:30 PM  EST', 'Wednesday': '8:30 AM - 4:30 PM  EST', 'Thursday': '8:30 AM - 4:30 PM  EST', 'Friday': '8:30 AM - 4:30 PM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program helps people who are older than 59 years old.', 'This program helps people with income at or below 130% of federal poverty guidelines.', 'A resident of PA (Delaware or Philadelphia County)']
# Latitude: 39.978413
# Longitude: -75.1408544
# ZIP Code: 19122
# Availability: waitlist
# Description: The Commodity Supplemental Food Program (CSFP) provides USDA-donated food to low-income seniors through monthly CSFP/senior boxes. Philabundance packs and distributes these boxes to strategically chosen locations throughout the Delaware Valley.This program provides:- Food to meet basic nutritional needs Boxes contain approximately 30 pounds of canned and boxed food including vegetables, fruit, juice, pasta, milk, cereal, canned meat and a non-meat protein.
# Languages: ['Arabic', 'Chinese', 'English', 'Haitian', 'Korean', 'Nepali', 'Russian', 'Spanish', 'Ukrainian', 'Vietnamese']
# Cost: Free
# Facebook URL: https://facebook.com/Philabundance
# Twitter URL: https://www.twitter.com/http://twitter.com/Philabundance
# Coverage Area: This program covers residents of the following counties: Delaware County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Hunger Programs - Senior Citizen Boxes
# URL:  https://www.auntbertha.com//feast-of-justice--philadelphia-pa--hunger-programs---senior-citizen-boxes/4899393198620672?postal=19131
# Reviewed on: 12/13/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages']
# Phone Number: 215-268-3510
# Location Address: 3101 Tyson Avenue, Philadelphia, PA 19149
# Location url map: https://www.google.com/maps/?q=3101+Tyson+Avenue,+Philadelphia,+PA+19149/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': '9:00 AM - 12:00 PM  EST', 'Wednesday': '4:00 PM - 7:00 PM  EST', 'Thursday': '10:00 AM - 12:00 PM  EST', 'Friday': 'Closed', 'Saturday': '10:00 AM - 4:00 PM  EST', 'Sunday': 'Closed'}
# Eligibility: ['This program serves individuals living in one of these zip codes: 19111, 19114, 19115, 19116, 19124, 19135, 19136, 19149, 19152, 19154']
# Latitude: 40.0372113
# Longitude: -75.052399
# ZIP Code: 19149
# Availability: available
# Description: Senior Citizen Boxes program offers plentiful programs to combat hunger in the community.This program provides:- A community cupboard, which provides families with emergency, supplemental food every month.Once you apply, it takes 1 to 2 months for your name to appear on the list.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/FeastOfJusticePhiladelphia/?view_public_for=170475529821804
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Bucks County, PA, Chester County, PA, Delaware County, PA, Montgomery County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//st.-mark%2527s-evangelical-lutheran-church--philadelphia-pa--food-pantry/5130149218746368?postal=19131
# Reviewed on: 12/14/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 215-224-1145
# Location Address: 6344 North Broad Street, Philadelphia, PA 19141
# Location url map: https://www.google.com/maps/?q=6344+North+Broad+Street,+Philadelphia,+PA+19141/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': '10:00 AM - 4:00 PM  EST', 'Wednesday': 'Closed', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.0502268
# Longitude: -75.1427263
# ZIP Code: 19141
# Availability: available
# Description: The food pantry provides quality food items to households experiencing food insecurity. This program supplies critical nutrition to hungry individuals and families. This program provides:- Food to meet nutritional needsPlease call the food pantry before visiting to verify hours of availability and any additional information.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/StMarksPhila/
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Social Services Program
# URL:  https://www.auntbertha.com//salvation-army-eastern-pennsylvania-%2526-delaware--philadelphia-pa--social-services-program/4620877509427200?postal=19131
# Reviewed on: 12/12/2024
# Main Services: ['food pantry', 'meals', 'clothing', 'toys & gifts', 'parenting education', 'counseling', 'financial education', 'navigating the system', 'support network', 'spiritual support', 'skills & training', 'interview training', 'resume development', 'help find work']
# Other Services: None
# Serving: ['all ages', 'individuals', 'families', 'homeless', 'near homeless', 'low-income']
# Phone Number: 215-474-1010
# Location Address: 5501 Market Street, Philadelphia, PA 19139
# Location url map: https://www.google.com/maps/?q=5501+Market+Street,+Philadelphia,+PA+19139/
# {'24_hour': False, 'Monday': '9:00 AM - 4:00 PM  EST', 'Tuesday': '9:00 AM - 4:00 PM  EST', 'Wednesday': '9:00 AM - 4:00 PM  EST', 'Thursday': '9:00 AM - 4:00 PM  EST', 'Friday': '9:00 AM - 4:00 PM  EST', 'Saturday': '9:00 AM - 4:00 PM  EST', 'Sunday': '9:00 AM - 4:00 PM  EST'}
# Eligibility: ['This program serves residents of Pennsylvania.']
# Latitude: 39.9610016
# Longitude: -75.2312927
# ZIP Code: 19139
# Availability: available
# Description: Salvation Army Eastern Pennsylvania & Delaware social workers provide social services to meet the needs of the community. This program provides:- Access to nutritious food- Counseling Services- Financial Education- Spiritual Support- Referrals- Help find work- Resume Building- Interview skills- Job placement- Toys & Gifts (Holiday season)- Clothing (all ages)- Men's and women's support groupsServices offered may change depending on location. Please contact the nearest office for more information.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/SalvationArmyPhiladelphia
# Twitter URL: https://www.twitter.com/@SalArmyPhilly
# Coverage Area: This program covers residents of the following cities: Dover, DE, Seaford, DE, Wilmington, DE, Allentown, PA, Berwick, PA, Bethlehem, PA, Boyertown, PA, Carlisle, PA, Chambersburg, PA, Chester, PA, Coal Township, PA, Coatesville, PA, Darby, PA, East Stroudsburg, PA, Easton, PA, Harrisburg, PA, Hazleton, PA, Lancaster, PA, Lebanon, PA, Levittown, PA, Lewistown, PA, Lock Haven, PA, Milton, PA, Norristown, PA, Pen Argyl, PA, Philadelphia, PA, Pottstown, PA, Pottsville, PA, Reading, PA, Scranton, PA, State College, PA, Sunbury, PA, Tamaqua, PA, West Chester, PA, Wilkes Barre, PA, Williamsport, PA and York, PA.
# ***************************************************************************
# Service name:  Free Produce Markets
# URL:  https://www.auntbertha.com//children%2527s-hospital-of-philadelphia-%2528chop%2529--philadelphia-pa--free-produce-markets/6006436119248896?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['all ages', 'individuals', 'families']
# No phone number found.
# Location Address: 4865 Market Street, Philadelphia, PA 19139
# Location url map: https://www.google.com/maps/?q=4865+Market+Street,+Philadelphia,+PA+19139/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': 'Closed', 'Thursday': '9:30 AM - 10:30 AM  EST', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: []
# Latitude: 39.9595846
# Longitude: -75.2176817
# ZIP Code: 19139
# Availability: available
# Description: CHOP's free produce markets provides quality food items to households experiencing food insecurity. This program supplies critical nutrition to hungry individuals and families.This program provides:- Food to meet basic nutritional needsPlease bring your own bag when you visit. The market will be cancelled if it rains.
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//star-of-hope-baptist-church--philadelphia-pa--food-pantry/5924269727678464?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# No phone number found.
# Location Address: 7212 Keystone Street, Philadelphia, PA 19135
# Location url map: https://www.google.com/maps/?q=7212+Keystone+Street,+Philadelphia,+PA+19135/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': '11:00 AM - 1:00 PM  EST', 'Wednesday': 'Closed', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.0271939
# Longitude: -75.0340536
# ZIP Code: 19135
# Availability: available
# Description: Star of Hope Baptist Church offers a food pantry which serves everyone from low income families, single parents, senior citizens, unemployed individuals, disabled veterans, working poor, and anyone else in need of assistance.This program provides: - Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/Star-of-Hope-Baptist-Church-147516732074440/
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//saint-paul%2527s-evangelical-lutheran-church--philadelphia-pa--food-pantry/6117146080575488?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families']
# Phone Number: 215-424-4800
# Location Address: 5900 North 5th Street, Philadelphia, PA 19120
# Location url map: https://www.google.com/maps/?q=5900+North+5th+Street,+Philadelphia,+PA+19120/
# {'24_hour': False, 'Monday': '9:00 AM - 12:00 PM  EST', 'Tuesday': 'Closed', 'Wednesday': '9:00 AM - 12:00 PM  EST', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.0414451
# Longitude: -75.1297938
# ZIP Code: 19120
# Availability: available
# Description: Saint Paul's Evangelical Lutheran Church helps alleviate hunger in the community in an environment of respect, care and hospitality.This program provides:- Foods to meet basic nutritional needsPlease call for any updated information.
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//church-of-the-holy-apostles-and-the-mediator--philadelphia-pa--food-pantry/6220814712832000?postal=19131
# Reviewed on: 12/19/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['all ages', 'individuals', 'families']
# Phone Number: 267-908-3287
# Location Address: 260 South 51st Street, Philadelphia, PA 19139
# Location url map: https://www.google.com/maps/?q=260+South+51st+Street,+Philadelphia,+PA+19139/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': '10:30 AM - 12:00 PM  EST', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves individuals and families who are facing food insecurity.']
# Latitude: 39.9548575
# Longitude: -75.2243414
# ZIP Code: 19139
# Availability: available
# Description: The Community Food Ministry distributes food monthly to community members in need. This program provides:- Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Food Pantry
# URL:  https://www.auntbertha.com//wayland-temple-baptist-church--philadelphia-pa--food-pantry/6384397462011904?postal=19131
# Reviewed on: 12/11/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['all ages', 'individuals', 'families']
# Phone Number: 215-769-0243
# Location Address: 2500 Cecil B. Moore Avenue, Philadelphia, PA 19121
# Location url map: https://www.google.com/maps/?q=2500+Cecil+B.+Moore+Avenue,+Philadelphia,+PA+19121/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': 'Closed', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': '8:30 AM - 1:00 PM  EST', 'Sunday': 'Closed'}
# Eligibility: []
# Latitude: 39.9807486
# Longitude: -75.1759246
# ZIP Code: 19121
# Availability: available
# Description: Wayland Temple Baptist Church provides supplemental groceries to individuals and families in need of assistance in the community.This program provides:- Food to meet basic nutritional needsFood is distributed on the 1st and 3rd Saturday of the month from 8:30 a.m. - 1:00 p.m. Please reach out by phone for more information on eligibility and distribution.
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  2 Fish 5 Loaves
# URL:  https://www.auntbertha.com//upper-room-baptist-church--philadelphia-pa--2-fish-5-loaves/6666371970760704?postal=19131
# Reviewed on: 11/13/2024
# Main Services: ['food pantry']
# Other Services: None
# Serving: ['anyone in need', 'all ages']
# Phone Number: 267-593-4989
# Location Address: 7236 Ogontz Avenue, Philadelphia, PA 19138
# Location url map: https://www.google.com/maps/?q=7236+Ogontz+Avenue,+Philadelphia,+PA+19138/
# {'24_hour': False, 'Monday': '10:00 AM - 12:00 PM  EST', 'Tuesday': '8:30 AM - 10:30 AM  EST', 'Wednesday': '8:30 AM - 10:30 AM  EST', 'Thursday': '10:00 AM - 12:00 PM  EST', 'Friday': '8:30 AM - 10:30 AM  EST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Latitude: 40.064768
# Longitude: -75.1550397
# ZIP Code: 19138
# Availability: available
# Description: The Room hosts a free food pantry to serve the members of the community fight hunger. This program provides:- Food to meet basic nutritional needs
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/groups/2460515280695286/
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************

# %%
# Save to CSV file 
#"FindHelp_extracted_data_riv_shelter.csv" is the name for the shelter csv for riv
#"FindHelp_extracted_data_riv_food_pantry.csv" is the name for the food pantry csv for riv
#"FindHelp_extracted_data_riv_mental_health.csv" is the name for the food pantry csv for riv
#"FindHelp_extracted_data_downtown_la_food_pantry.csv" is the name for the food pantry csv for downtown la
csv_filename = "Philadelphia(19131-19154)_Food_Pantry_Chenzi.csv"

with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # The header 
    header = [
        "Service_name",
        "Service_url",
        "Main_Services",
        "Other_Services",
        "Serving",
        "Phone_Number",
        "Website",
        "Location_Address",
        "Location_URL_Map",
        "Eligibility",
        "Availability",
        "Description",
        "Languages",
        "Cost",
        "Google_Review",
        "Facebook_URL",
        "Twitter_URL",
        "Coverage",
        "Latitude",
        "Longitude",
        "Zipcode",
        "24hour",
        "Monday",
        "Tuesday",
        "Wednesday",
        "Thursday",
        "Friday",
        "Saturday",
        "Sunday"
    ]
    csv_writer.writerow(header)
    
    csv_writer.writerows(data)

# %%
#"FindHelp_extracted_data_riv_shelter.csv" is the name for the shelter csv
#"FindHelp_extracted_data_riv_food_pantry.csv" is the name for the food pantry csv
#"FindHelp_extracted_data_riv_mental_health.csv" is the name for the food pantry csv
#"FindHelp_extracted_data_downtown_la_food_pantry.csv"
#"FindHelp_extracted_data_downtown_la_shelter.csv"
#"FindHelp_extracted_data_downtown_la_mental_health.csv"
#"FindHelp_extracted_data_irvine_food_pantry.csv"
#"FindHelp_extracted_data_irvine_shelter.csv"
#"FindHelp_extracted_data_irvine_mental_health.csv"
df = pd.read_csv("Philadelphia(19131-19154)_Food_Pantry_Chenzi.csv")

#riv_zipcodes = [92501, 92502, 92503, 92504, 92505, 92506, 92507, 92508, 92513, 92514, 92516, 92517, 92521, 92522]

#downtown_la_zipcodes = [90012, 90013, 90014, 90015, 90017, 90021]

#irvine_zipcodes = [92602, 92603, 92604, 92606, 92612, 92614, 92617, 92618, 92620]

Philadelphia_zipcodes = [19131, 19132, 19133, 19134, 19135, 19136, 19137, 19138, 19139, 19140, 19141, 19142, 19143, 19144, 19145, 19146, 19147, 19148, 19149, 19150, 19151, 19152, 19153, 19154]

filtered_df = df[df['Zipcode'].isin(Philadelphia_zipcodes) | (df['Location_Address'].isna() & df['Longitude'].isna() & df['Latitude'].isna())]

filtered_df = filtered_df.drop_duplicates(subset = ['Website', 'Service_name'])

filtered_df.to_csv("Philadelphia(19131-19154)_Food_Pantry_Chenzi.csv", index=False, encoding='utf-8')

filtered_df
# Out:
#                 Service_name  \
# 1          Food Distribution
# 3                Food Pantry
# 5              Resource Fair
# 6                Food Pantry
# 7           Farm to Families
# ..                       ...
# 113  Social Services Program
# 114     Free Produce Markets
# 115              Food Pantry
# 117              Food Pantry
# 119          2 Fish 5 Loaves
#
#                                            Service_url  \
# 1    https://www.auntbertha.com//north10%252C-phila...
# 3    https://www.auntbertha.com//st.-barbara%2527s-...
# 5    https://www.auntbertha.com//the-simple-way--ph...
# 6    https://www.auntbertha.com//the-salvation-army...
# 7    https://www.auntbertha.com//st.-christopher%25...
# ..                                                 ...
# 113  https://www.auntbertha.com//salvation-army-eas...
# 114  https://www.auntbertha.com//children%2527s-hos...
# 115  https://www.auntbertha.com//star-of-hope-bapti...
# 117  https://www.auntbertha.com//church-of-the-holy...
# 119  https://www.auntbertha.com//upper-room-baptist...
#
#                                          Main_Services  \
# 1                                      ['food pantry']
# 3                                      ['food pantry']
# 5    ['food pantry', 'clothing', 'navigating the sy...
# 6                                      ['food pantry']
# 7                                      ['food pantry']
# ..                                                 ...
# 113  ['food pantry', 'meals', 'clothing', 'toys & g...
# 114                                    ['food pantry']
# 115                                    ['food pantry']
# 117                                    ['food pantry']
# 119                                    ['food pantry']
#
#               Other_Services  \
# 1                        NaN
# 3                        NaN
# 5                        NaN
# 6                        NaN
# 7    ['nutrition education']
# ..                       ...
# 113                      NaN
# 114                      NaN
# 115                      NaN
# 117                      NaN
# 119                      NaN
#
#                                                Serving  Phone_Number  \
# 1    ['anyone in need', 'all ages', 'individuals', ...  267-908-9000
# 3    ['anyone in need', 'all ages', 'individuals', ...  215-473-1044
# 5    ['anyone in need', 'all ages', 'individuals', ...  215-423-3598
# 6    ['anyone in need', 'all ages', 'individuals', ...  215-825-4601
# 7    ['anyone in need', 'all ages', 'individuals', ...  484-734-0189
# ..                                                 ...           ...
# 113  ['all ages', 'individuals', 'families', 'homel...  215-474-1010
# 114            ['all ages', 'individuals', 'families']           NaN
# 115  ['anyone in need', 'all ages', 'individuals', ...           NaN
# 117            ['all ages', 'individuals', 'families']  267-908-3287
# 119                     ['anyone in need', 'all ages']  267-593-4989
#
#                                                Website  \
# 1              https://north10phl.org/health-wellness/
# 3        https://stbarbphila.org/events/food-pantry-ph
# 5                 https://thesimpleway.org/what-we-do/
# 6    https://easternusa.salvationarmy.org/eastern-p...
# 7    https://scfchildren.org/farm-to-families-initi...
# ..                                                 ...
# 113              https://easternusa.salvationarmy.org/
# 114                                                NaN
# 115       https://www.starofhopebc.org/weekly-bulletin
# 117       https://www.hamphilly.org/copy-of-ministries
# 119              https://urmbc.org/community-outreach/
#
#                                    Location_Address  \
# 1    3890 North 10th Street, Philadelphia, PA 19140
# 3       5359 Lebanon Avenue, Philadelphia, PA 19131
# 5        3234 Potter Street, Philadelphia, PA 19134
# 6        5501 Market Street, Philadelphia, PA 19139
# 7        4865 Market Street, Philadelphia, PA 19139
# ..                                              ...
# 113      5501 Market Street, Philadelphia, PA 19139
# 114      4865 Market Street, Philadelphia, PA 19139
# 115    7212 Keystone Street, Philadelphia, PA 19135
# 117   260 South 51st Street, Philadelphia, PA 19139
# 119      7236 Ogontz Avenue, Philadelphia, PA 19138
#
#                                       Location_URL_Map  \
# 1    https://www.google.com/maps/?q=3890+North+10th...
# 3    https://www.google.com/maps/?q=5359+Lebanon+Av...
# 5    https://www.google.com/maps/?q=3234+Potter+Str...
# 6    https://www.google.com/maps/?q=5501+Market+Str...
# 7    https://www.google.com/maps/?q=4865+Market+Str...
# ..                                                 ...
# 113  https://www.google.com/maps/?q=5501+Market+Str...
# 114  https://www.google.com/maps/?q=4865+Market+Str...
# 115  https://www.google.com/maps/?q=7212+Keystone+S...
# 117  https://www.google.com/maps/?q=260+South+51st+...
# 119  https://www.google.com/maps/?q=7236+Ogontz+Ave...
#
#                                            Eligibility  ...  Longitude  \
# 1                  ['Anyone can access this program.']  ... -75.144428
# 3                  ['Anyone can access this program.']  ... -75.231451
# 5                  ['Anyone can access this program.']  ... -75.112190
# 6                  ['Anyone can access this program.']  ... -75.231293
# 7              ['Must be eligible for SNAP benefits.']  ... -75.217549
# ..                                                 ...  ...        ...
# 113  ['This program serves residents of Pennsylvani...  ... -75.231293
# 114                                                 []  ... -75.217682
# 115                ['Anyone can access this program.']  ... -75.034054
# 117  ['This program serves individuals and families...  ... -75.224341
# 119                ['Anyone can access this program.']  ... -75.155040
#
#      Zipcode 24hour                    Monday                  Tuesday  \
# 1    19140.0  False                    Closed  10:00 AM - 2:00 PM  EST
# 3    19131.0  False                    Closed                   Closed
# 5    19134.0  False   12:30 PM - 2:30 PM  EST  12:30 PM - 2:30 PM  EST
# 6    19139.0  False    9:00 AM - 2:00 PM  EST   9:00 AM - 2:00 PM  EST
# 7    19139.0  False                    Closed                   Closed
# ..       ...    ...                       ...                      ...
# 113  19139.0  False    9:00 AM - 4:00 PM  EST   9:00 AM - 4:00 PM  EST
# 114  19139.0  False                    Closed                   Closed
# 115  19135.0  False                    Closed  11:00 AM - 1:00 PM  EST
# 117  19139.0  False                    Closed                   Closed
# 119  19138.0  False  10:00 AM - 12:00 PM  EST  8:30 AM - 10:30 AM  EST
#
#                     Wednesday                  Thursday  \
# 1                      Closed   10:00 AM - 2:00 PM  EST
# 3     12:00 PM - 2:00 PM  EST                    Closed
# 5                      Closed                    Closed
# 6      9:00 AM - 2:00 PM  EST    9:00 AM - 2:00 PM  EST
# 7                      Closed   11:00 AM - 3:00 PM  EST
# ..                        ...                       ...
# 113    9:00 AM - 4:00 PM  EST    9:00 AM - 4:00 PM  EST
# 114                    Closed   9:30 AM - 10:30 AM  EST
# 115                    Closed                    Closed
# 117  10:30 AM - 12:00 PM  EST                    Closed
# 119   8:30 AM - 10:30 AM  EST  10:00 AM - 12:00 PM  EST
#
#                       Friday                Saturday                  Sunday
# 1                     Closed                  Closed                  Closed
# 3                     Closed                  Closed                  Closed
# 5    9:30 AM - 11:30 AM  EST                  Closed                  Closed
# 6     9:00 AM - 2:00 PM  EST                  Closed                  Closed
# 7                     Closed                  Closed                  Closed
# ..                       ...                     ...                     ...
# 113   9:00 AM - 4:00 PM  EST  9:00 AM - 4:00 PM  EST  9:00 AM - 4:00 PM  EST
# 114                   Closed                  Closed                  Closed
# 115                   Closed                  Closed                  Closed
# 117                   Closed                  Closed                  Closed
# 119  8:30 AM - 10:30 AM  EST                  Closed                  Closed
#
# [68 rows x 29 columns]
