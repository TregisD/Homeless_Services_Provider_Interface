# %%
from bs4 import BeautifulSoup
import csv
import re
import os 
import pandas as pd
import glob

# %%
data = []

# reading html files from folder

#'Riv_Shelter_HTML_Files'is the name for the shelter HTML Files Riverside
#'Riv_Food_Pantry_HTML_Files'is the name for the food pantry HTML Files for Riverside 
#'Riv_Mental_Health_HTML_Files'is the name for the mental health HTML Files for Riverside
#'Downtown_LA_Food_Pantry_HTML_Files' is the name for the food pantry HTML Files for downtown LA
#'Irvine_Mental_Health_HTML_Files' is the name for the mental health HTML Files for Irvine
folder_path = 'Chenzi/Chenzi Temp Shelter HTML'

# Loop through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.html'):
        file_path = os.path.join(folder_path, filename)

        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()

        soup = BeautifulSoup(html_content, 'html.parser')


        # Find the <ul> element with class "best-programs"
        ul_element = soup.find('ul', {'class': 'best-programs'})

        # Find all <li> elements within the <ul>
        li_elements = ul_element.find_all('li', {'class': 'search-result card card-v3 program-info'})

        # Loop through the found <li> elements and extract labels and values
        for li_element in li_elements:
            # Use BeautifulSoup to parse the HTML of each li_element
            li_soup = BeautifulSoup(str(li_element), 'html.parser')

            # Find the program heading 
            program_heading_element = li_soup.find('div', {'class': 'card-heading'})
            Service_name = program_heading_element.find('a', {'class': 'activity-log ph-flyout-click cwdc-flyout-click click-cookie'}).text
            print('Service name: ', Service_name)
    
            # Extract program URL
            program_url_element = program_heading_element.find('a', {'class': 'activity-log ph-flyout-click cwdc-flyout-click click-cookie'})
            program_url = program_url_element['href'] if program_url_element else None
            Service_url = "https://www.auntbertha.com/"+program_url
            print('URL: ', Service_url)
            
            is_reviewed = False

            # Reviewed on
            Reviewd_on_element = program_heading_element.find('div', {'class': 'last-reviewed'})
            if Reviewd_on_element:  # Check if the element exists
                Reviewd_on_text = Reviewd_on_element.get_text(strip=True)  # Clean up the text
                match = re.search(r'\d{2}/\d{2}/\d{4}', Reviewd_on_text)
                Reviewd_on = match.group() if match else None
                if Reviewd_on:  # If we found a review date
                    is_reviewed = True  # Set the flag to True
                print("Reviewed on:", Reviewd_on)
            else:
                Reviewd_on = None  # Set to None if not found
                print("No review date found.")
    
            # Access class="program-tags"
            program_tags = li_soup.find('div', {'class': 'program-tags'})

            # Main Services
            main_s = []
            main_service_list = program_tags.find('ul', {'class': 'list-inline'})
            main_service_items = main_service_list.find_all('li')

            for item in main_service_items:
                main_service = item.find('a', {'class': 'loading-on-click activity-log'}).text.strip()
                main_s.append(main_service)

            print("Main Services:", main_s)

            # Try to access the "Other Services" section
            other_service_list = program_tags.find('div', {'class': 'secondary-tags'})
            if other_service_list:
                other_s = []
                other_service_items = other_service_list.find('ul', {'class': 'list-inline'}).find_all('li')

                for item in other_service_items:
                    other_service = item.find('a', {'class': 'loading-on-click activity-log'}).text.strip()
                    other_s.append(other_service)
            else:
                other_s = None

            print("Other Services:", other_s)

            # Access the "Serving" section
            serving_section = program_tags.find('div', {'class': 'attribute-tags'})

            # Initialize a list to store the serving information
            serving_ = []
    
            # Find all the <li> elements within the serving section
            serving_items = serving_section.find_all('li')

            # Iterate through the serving items and extract the text from the <a> elements
            for item in serving_items:
                link = item.find('a', {'class': 'loading-on-click activity-log'})
    
                # Check if the link was found
                if link:  # Only proceed if the link exists
                    serving_text = link.text.strip()
                    serving_.append(serving_text)

            print("Serving:", serving_)

    
            # accessing next-steps-module, extract phone number, location, hours 
    
            next_steps_module = li_soup.find('div', {'class': 'next-steps-module'})

            # Extract phone number
            phone_number_elements = next_steps_module.find_all('span', {'class': 'result-next-step-item'})

            # Also find all 'a' elements with href attributes containing 'tel:'
            tel_link_elements = next_steps_module.find_all('a', href=True)

            phone_number = None  # Initialize phone number as None

            # Extract phone numbers from text-based spans
            for element in phone_number_elements:
                phone_number_text = element.text.strip() if element else None
    
                # Regex to extract digits (handling separators like spaces or hyphens)
                phone_number_matches = re.findall(r'[\d-]+', phone_number_text)
    
                # Join the digits into a single phone number string if matches are found
                if phone_number_matches:
                    phone_number = ''.join(phone_number_matches)
                    break  # Stop once we've found a phone number

            # If no phone number found from text, check the 'tel:' href links
            if not phone_number:
                for element in tel_link_elements:
                    href_value = element['href']
        
                    # Check if the href contains 'tel:' and extract digits
                    if 'tel:' in href_value:
                        phone_number_matches = re.findall(r'[\d-]+', href_value)
                        if phone_number_matches:
                            phone_number = ''.join(phone_number_matches)
                            break  # Stop once we've found a phone number

            # Print the extracted phone number
            if phone_number:
                print("Phone Number:", phone_number)
            else:
                print("No phone number found.")

            # Extract location address
            location_address_element = next_steps_module.find('a', {'class': 'activity-log ph-flyout-click cwdc-flyout-click map-link with-address'})
            location_address = location_address_element.text.strip() if location_address_element else None
            location_address = re.sub(r'\s+', ' ', location_address) if location_address_element else None
            print("Location Address:", location_address)

            # Extract URL
            location_url_map = location_address_element['href'] if location_address_element else None
            print("Location url map:", location_url_map)
            
            hours_info = {
                '24_hour': False,
                'Monday': None,
                'Tuesday': None,
                'Wednesday': None,
                'Thursday': None,
                'Friday': None,
                'Saturday': None,
                'Sunday': None
            }
            
            # Extract hours based on structure
            hours_element = next_steps_module.find('div', {'class': 'office-hours-schedule see-hours-dropdown'})
            if hours_element:
                # Find all the <span> elements within the hours_element
                day_spans = hours_element.find_all('span')

                # Ensure that we have even pairs of day and corresponding hours
                if len(day_spans) % 2 == 0:
                    # Iterate through the spans in pairs (day and its corresponding hours)
                    for i in range(0, len(day_spans), 2):
                        day_span = day_spans[i]          # This is the day (e.g., "Monday:")
                        hours_span = day_spans[i + 1]    # This is the corresponding hours (e.g., "Closed" or time)

                        # Extract the day name and remove the colon
                        day = day_span.text.strip()[:-1]  # Remove the ':' at the end
                        full_day = day.strip()            # Ensure there's no extra space

                        # Check if the day is valid and exists in hours_info
                        if full_day in hours_info:
                            # Check if the corresponding hours span indicates "Closed"
                            if 'Closed' in hours_span.text:
                                hours_info[full_day] = 'Closed'
                            else:
                                # Extract hours for non-closed days
                                hours_info[full_day] = hours_span.text.strip()
                else:
                    print("Unexpected hours format. Ensure that each day has corresponding hours.")

            # Handle 24-hour information if it exists
            else:
                hours_element = next_steps_module.find('span', {'class': 'result-geo-hours'})
                if hours_element:
                    # Get 24-hour text strip
                    hours_text = hours_element.get_text(strip=True)

                    # Assuming the presence of this text means 24-hour operation
                    if '24' in hours_text or '24-hour' in hours_text.lower():
                        hours_info['24_hour'] = True
                    else:
                        print("Unable to determine if the office is 24 hours.")
                else:
                    print("Hours information not available.")

            # Output the result
            print(hours_info)
    
    
            # Loop through the found <li> elements and extract labels and values
            Extra_element = li_element.find('div', {'class': 'panel-wrapper more-info-panel'})
            elig = []
            eligibility_rules_element = Extra_element.find('div', {'class': 'eligibility-rules'})
    
            # Check if eligibility_rules_element is found
            if eligibility_rules_element:
                # Check if eligibility_rules_element contains a list (ul)
                ul_element = eligibility_rules_element.find('ul')
        
                if ul_element:
                    # If it contains a list, extract list items and store them in a flat list
                    eligibility_list = [li.text.strip() for li in ul_element.find_all('li')]
                    elig.extend(eligibility_list)  # Use extend to add elements to the list directly
                    #print("Eligibility:", eligibility_list)
                else:
                    # If it doesn't contain a list, store the text as is
                    eligibility_text = eligibility_rules_element.text.strip()
                    #print("Eligibility:", [eligibility_text])  # Wrap in a list to maintain consistency
                    elig.append(eligibility_text)

            else:
                # Skip if 'eligibility-rules' class is not found
                pass
    
        
            print("Eligibility:", elig)
    
            # Extract Availability
            availability_element = Extra_element.find('strong', {'data-translate': 'Availability'})
            
            if availability_element:
                availability = availability_element.find_next('div', {'class': 'col-md-10'}).text.strip()
            else:
                availability = "Not specified"

            # Extract Description
            description_element = Extra_element.find('strong', {'data-translate': 'Description'})
            description = description_element.find_next('div', {'class': 'col-md-10'}).text.strip()

            # Extract Languages
            languages_element = Extra_element.find('strong', {'data-translate': 'Languages'})
            languages = languages_element.find_next('div', {'class': 'col-md-10'}).text.strip()
            languages_data = [lang.strip() for lang in languages.split(',')]
            
            # Extract Cost
            cost_element = Extra_element.find('strong', string='Cost:')
            
            if cost_element:  # Check if cost_element exists
                cost = cost_element.find_next('div', {'class': 'col-md-10'}).text.strip()
            else:
                cost = "Not specified"  # Default value if cost_element is not found
            
            # Extract Website URLs if they exist, or set them to None
            website_element = Extra_element.find('div', {'data-translation': 'Website'})
            website_url = website_element.find_next('a', {'class': 'activity-log descriptionProgramWebsite'})['href'] if website_element else None

            # Extract Facebook and Twitter URLs if they exist, or set them to None
            facebook_element = Extra_element.find('strong', {'data-translate': 'Facebook'})
            facebook_url = facebook_element.find_next('a', {'class': 'activity-log descriptionProgramFacebook'})['href'] if facebook_element else None

            twitter_element = Extra_element.find('strong', {'data-translate': 'Twitter'})
            twitter_url = twitter_element.find_next('a', {'class': 'activity-log descriptionProgramTwitter'})['href'] if twitter_element else None

            # Extract Coverage Area
            coverage_element = Extra_element.find('strong', {'data-translate': 'Coverage Area'})
            coverage = coverage_element.find_next('div', {'class': 'col-md-10'}).text.strip()
            
            # Initialize latitude and longitude as None by default
            latitude = None
            longitude = None
            zipcode = None

            # Find the element with class "office-hour-address"
            location_element = Extra_element.find('div', {'class': 'office-hours-address _js_address address notranslate'})

            # Check if the element exists and has the required attributes
            if location_element:
                latitude = location_element['data-latitude'] if location_element.has_attr('data-latitude') else None
                longitude = location_element['data-longitude'] if location_element.has_attr('data-longitude') else None
                print("Latitude:", latitude)
                print("Longitude:", longitude)
                
                # Extract all text within location_element
                address_text = location_element.get_text(separator=" ").strip()  # Get all text as a single string

                # Use regular expression to search for the ZIP code pattern anywhere in the text
                zip_matches = re.findall(r'(?<!\d)(\b\d{5}\b)(?!\d)', address_text)
                zipcode = int(zip_matches[-1]) if zip_matches else None
                print("ZIP Code:", zipcode)

            # Print or use the extracted values as needed
            print("Availability:", availability)
            print("Description:", description)
            print("Languages:", languages_data)
            print("Cost:", cost)
            print("Facebook URL:", facebook_url)
            print("Twitter URL:", twitter_url)
            print("Coverage Area:", coverage)

            data.append([
            Service_name,
            Service_url,
            main_s,
            other_s,
            serving_,
            phone_number,
            website_url,
            location_address,
            location_url_map,
            elig,
            availability,
            description,
            languages_data,
            cost,
            is_reviewed,
            facebook_url,
            twitter_url,
            coverage,
            latitude,
            longitude,
            zipcode,
            hours_info['24_hour'],
            hours_info['Monday'],      
            hours_info['Tuesday'],     
            hours_info['Wednesday'],   
            hours_info['Thursday'],   
            hours_info['Friday'],     
            hours_info['Saturday'],  
            hours_info['Sunday']])    
            print("***************************************************************************")
# Out:
# Service name:  Drop In Center
# URL:  https://www.auntbertha.com//prevention-point-philadelphia-%2528ppp%2529--philadelphia-pa--drop-in-center/5089660355477504?postal=19131
# Reviewed on: 12/14/2024
# Main Services: ['weather relief', 'meals', 'addiction & recovery', 'medical care', 'navigating the system', 'case management', 'one-on-one support', 'advocacy & legal aid']
# Other Services: None
# Serving: ['adults 18+', 'individuals', 'families']
# No phone number found.
# Location Address: 2915 Kensington Avenue, Philadelphia, PA 19134
# Location url map: https://www.google.com/maps/?q=2915+Kensington+Avenue,+Philadelphia,+PA+19134/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves residents in Philadelphia county, PA.']
# Latitude: 39.9927854
# Longitude: -75.1196455
# ZIP Code: 19134
# Availability: available
# Description: The Drop In Center strives to be free of judgment, allowing people of all backgrounds to come in and relax. The Drop In Center is in many ways the gateway through which participants are connected to the many services provided by PPP. This program provides:- Case management- HIV/HCV testing and counseling- Mail services- Legal clinic- Medical services- CRAFT (links participants to addiction treatment)- Specialized surveys - MealsThe Drop In Center is open five days a week and provides daily respite for clients from outside weather.
# Languages: ['English', 'Spanish']
# Cost: Free
# Facebook URL: https://www.facebook.com/preventionpointphiladelphia
# Twitter URL: https://www.twitter.com/@preventionpp
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Various Community Events & Programs
# URL:  https://www.auntbertha.com//conquerors-community-development-corporation-%2528ccdc%2529--philadelphia-pa--various-community-events-%2526-programs/5390636500647936?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['community support services', 'weather relief', 'exercise & fitness', 'recreation', 'computer or internet access']
# Other Services: ['community support services', 'weather relief', 'exercise & fitness', 'recreation', 'computer or internet access']
# Serving: ['anyone in need', 'all ages', 'adults', 'young adults', 'teens', 'infants', 'children', 'seniors', 'adults 18+', 'criminal justice history', 'covid19', 'dropouts', 'students', 'employed', 'retirement', 'unemployed', 'female', 'male', 'individuals', 'families', 'with children', 'home owners', 'home renters', 'near homeless', 'benefit recipients', 'low-income', 'uninsured', 'underinsured', 'caregivers', 'spouses', 'dependents', 'fathers', 'mothers', 'parents', 'in crisis', 'in danger', 'emergency']
# Phone Number: 215-474-2717
# Location Address: 5220 Whitby Avenue, Philadelphia, PA 19143
# Location url map: https://www.google.com/maps/?q=5220+Whitby+Avenue,+Philadelphia,+PA+19143/
# Hours information not available.
# {'24_hour': False, 'Monday': None, 'Tuesday': None, 'Wednesday': None, 'Thursday': None, 'Friday': None, 'Saturday': None, 'Sunday': None}
# Eligibility: []
# Latitude: 39.9463281
# Longitude: -75.2273043
# ZIP Code: 19143
# Availability: full
# Description: The Conquerors Community Development Corporation (CCDC) hosts Various Community Events & Programs that help to elevate the quality of life for the West and Southwest Philadelphia communities.  We host the 51st Ward Register Community Organization (RCO) Mondays 6pm-8pm and a number of other Community engagement events throughout the year with the following being held annually:1) Community Health Fair – A host of healthcare agencies provide access to a wide-range of information and services for our neighbors.2) Back 2 School Community Day – The CCDC partners with Victory Christian Center for our back-to-school event which includes refreshments, activities and entertainment for kids, parents and guardians. We provide information about programs and services for children, new backpacks, and school supplies.3) Senior Thanksgiving Luncheon – In partnership with the United Block Captains Association (UBCA) and Victory Christian Center, we host a Thanksgiving Dinner style luncheon for the senior in the neighborhood.4) Christmas at Victory Village – Through our annual Toy Drive at Victory Christian Center and with Coats received from the YMCA in partnership with Auto Dealers CARing for Kids Foundation, we provide a new coat, a toy, and book for children in need. This is a festive and lively event that includes food, music and entertainment for families during the holiday season.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/CCDCPhilly/
# Twitter URL: https://www.twitter.com/@vcc_philly
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Navigation Center
# URL:  https://www.auntbertha.com//horizon-house--philadelphia-pa--navigation-center/6224216144216064?postal=19131
# Reviewed on: 12/19/2024
# Main Services: ['temporary shelter', 'clothing', 'personal hygiene', 'navigating the system', 'meals']
# Other Services: None
# Serving: ['homeless', 'all ages']
# Phone Number: 215-232-1984
# Location Address: 5901 Market Street, Philadelphia, PA 19104
# Location url map: https://www.google.com/maps/?q=5901+Market+Street,+Philadelphia,+PA+19104/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves people experiencing homelessness.']
# Latitude: 39.962058
# Longitude: -75.2391324
# ZIP Code: 19104
# Availability: available
# Description: Navigation Center offers service-resistant homeless individuals the chance to gain stability by offering to meet their immediate needs by providing basic human services.Services include:- Temporary shelter- Food- Showers - Season-appropriate clothing- Resources for other human servicesFor more information, please call the Outreach Coordination Center's 24-hour hotline: 215-232-1984.
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Overnight Services
# URL:  https://www.auntbertha.com//horizon-house--philadelphia-pa--overnight-services/6301124945248256?postal=19131
# Reviewed on: 12/19/2024
# Main Services: ['temporary shelter']
# Other Services: ['meals', 'personal hygiene', 'mental health evaluation', 'one-on-one support']
# Serving: ['adults 18+', 'homeless']
# Phone Number: 215-386-383812603
# Location Address: 5901 Market Street, Philadelphia, PA 19136
# Location url map: https://www.google.com/maps/?q=5901+Market+Street,+Philadelphia,+PA+19136/
# {'24_hour': True, 'Monday': None, 'Tuesday': None, 'Wednesday': None, 'Thursday': None, 'Friday': None, 'Saturday': None, 'Sunday': None}
# Eligibility: ['This program serves homeless individuals.']
# Latitude: 39.962058
# Longitude: -75.2391324
# ZIP Code: 19136
# Availability: available
# Description: The Horizon House Navigation Center in West Philadelphia offers a variety of support services to homeless adults all year round. Here, people have a safe haven to meet their basic needs. The center is open 7 p.m. to 6 a.m. and is available on a drop-in basis.  Services include:- Temporary shelter- Food- Shower- Clean clothing- Laundry facilities- Medical and psychiatric assessments- Case managementExtended daytime hours are available two days/week for medical and psychiatric assessments and referral services. Case management services are offered to link individuals with appropriate housing, benefits, medical care and treatment services.For more information, please call at 215-386-3838, ext. 12603
# Languages: ['English']
# Cost: Reduced Cost
# Facebook URL: https://www.facebook.com/horizonhouseinc/?fref=ts
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Youth Emergency Service (YES)
# URL:  https://www.auntbertha.com//youth-service%252C-inc--philadelphia-pa--youth-emergency-service-%2528yes%2529/5680777996009472?postal=19131
# Reviewed on: 12/16/2024
# Main Services: ['temporary shelter', 'counseling', 'navigating the system', 'support network']
# Other Services: ['meals', 'sex education', 'medical care', 'disease screening', 'more education', 'screening & exams']
# Serving: ['teens', 'children', 'homeless', 'runaways', 'in crisis', 'emergency']
# Phone Number: 215-787-0633
# Location Address: 1526 Fairmount Avenue, Philadelphia, PA 19130
# Location url map: https://www.google.com/maps/?q=1526+Fairmount+Avenue,+Philadelphia,+PA+19130/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program helps people who are 12 to 17 years old.']
# Latitude: 39.9668498
# Longitude: -75.1630885
# ZIP Code: 19130
# Availability: available
# Description: Youth Emergency Service (YES) offers immediate housing, respite, and support services to youth ages 12-17 facing housing insecurity or are unable to safely live with family. YES Services include:- Twenty four hour emergency respite and protection for youth ages 12-17- Telephone hotline and referral services as well as links to national runaway and homeless youth providers through national Runaway Safeline and National safe Place- Medical care – examinations and follow-up- Counseling supports and referrals- Voluntary and confidential HIV testing- Linkage to The Attic for those wanting service for LGBTQ youth- Physical and sexual health information and supports- Referral to home based services for families- Education and recreation programming and supports- Title I tutoringYouth can be self referred, enter through the formal child welfare system, Department of Human Services, or through referrals from partner organizations throughout the county. Referrals come from family, school staff and other concerned persons.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/ysiyouthserviceinc
# Twitter URL: https://www.twitter.com/@YSIPHILLY
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  City of Philadelphia, Office of Homeless Services - Prevention, Diversion and Intake
# URL:  https://www.auntbertha.com//city-of-philadelphia---office-of-homeless-services--philadelphia-pa--city-of-philadelphia%252C-office-of-homeless-services---prevention%252C-diversion-and-intake/6101823548030976?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['emergency payments', 'help pay for housing', 'help pay for utilities', 'temporary shelter', 'financial assistance', 'financial education']
# Other Services: None
# Serving: ['adults 18+', 'individuals', 'families', 'home renters', 'near homeless', 'limited english']
# Phone Number: 215-686-7177
# Location Address: 804 North Broad Street, Philadelphia, PA 19130
# Location url map: https://www.google.com/maps/?q=804+North+Broad+Street,+Philadelphia,+PA+19130/
# {'24_hour': False, 'Monday': '4:00 AM - 2:00 PM  PST', 'Tuesday': '4:00 AM - 2:00 PM  PST', 'Wednesday': '4:00 AM - 2:00 PM  PST', 'Thursday': '4:00 AM - 2:00 PM  PST', 'Friday': '4:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program helps people with income at or below 125% of federal poverty guidelines.', 'Must be experiencing a financial crisis and at imminent risk of becoming homeless. OR', 'Received a court eviction hearing notice or court-ordered eviction. OR', 'Received a notice to vacate from landlord. OR', 'Lack family and financial resources, placing you at risk for homelessness. OR', 'Have the ability to sustain housing after receiving assistance.']
# Latitude: 39.968264
# Longitude: -75.1606146
# ZIP Code: 19130
# Availability: available
# Description: The City of Philadelphia - Office of Homeless Services provides limited emergency financial assistance and/or emergency response for families and individuals displaced or experiencing homelessness and residents with court-ordered evictions.This program provides:- Mediation- Financial Counseling- Problem solving- One-time payment for move-in costs (security deposit, first and last month’s rent)- Up to 12 months of rental assistance with housing case management- Emergency Housing (shelter)Assistance is available for residents displaced by disasters, natural and otherwise. Due to high call volume, OHS staff will return calls within 5 to 10 business days. Assistance is based on funding availability.Please call for updated information on available funding for assistance.
# Languages: ['English', 'Spanish']
# Cost: Free
# Facebook URL: https://www.facebook.com/pages/Philadelphia-PA/City-of-Philadelphia/23587514958
# Twitter URL: https://www.twitter.com/@PhiladelphiaGov
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Code Blue
# URL:  https://www.auntbertha.com//project-home--philadelphia-pa--code-blue/5982309675433984?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['temporary shelter', 'weather relief']
# Other Services: ['transportation', 'help hotlines']
# Serving: ['anyone in need', 'all ages', 'individuals', 'homeless']
# Phone Number: 215-232-1984
# Location Address: 1401 John F Kennedy Boulevard, Philadelphia, PA 19102
# Location url map: https://www.google.com/maps/?q=1401+John+F+Kennedy+Boulevard,+Philadelphia,+PA+19102/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves homeless individuals.']
# Latitude: 39.9540966
# Longitude: -75.1644793
# ZIP Code: 19102
# Availability: available
# Description: Project HOME provides an emergency shelter when it issues an emergency warning Code Blue. Code Blue is when the National Weather Service predicts wind chills of 20 degrees or lower or precipitation with temperatures below 32 degrees to preserve the lives of chronically homeless individuals.This program provides:- Short-term emergency shelterCity officials are urging the public to call Homeless Outreach at any time if they see someone who is homeless and sleeping on the street. Homeless outreach teams are available 24 hours a day, seven days a week.
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: https://www.twitter.com/@PHLCityHomeless
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Cooling Centers
# URL:  https://www.auntbertha.com//city-of-philadelphia---office-of-emergency-management-%2528oem%2529--philadelphia-pa--cooling-centers/4804499150602240?postal=19131
# Reviewed on: 12/13/2024
# Main Services: ['weather relief']
# Other Services: None
# Serving: ['anyone in need', 'all ages', 'individuals', 'families', 'homeless']
# No phone number found.
# Location Address: None
# Location url map: None
# {'24_hour': False, 'Monday': '8:00 AM - 5:00 PM', 'Tuesday': '8:00 AM - 5:00 PM', 'Wednesday': '8:00 AM - 5:00 PM', 'Thursday': '8:00 AM - 5:00 PM', 'Friday': '8:00 AM - 5:00 PM', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Anyone can access this program.']
# Availability: available
# Description: In the event of extreme heat and humidity, the City of Philadelphia opens cooling centers, which are air-conditioned spaces available for public use.This program provides:- Relief from extreme weatherVisit the website to find a cooling center located near you.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/cityofphiladelphia
# Twitter URL: https://www.twitter.com/@PhiladelphiaGov
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Emergency Safe Havens
# URL:  https://www.auntbertha.com//women-against-abuse--philadelphia-pa--emergency-safe-havens/5652293370249216?postal=19131
# Reviewed on: 12/16/2024
# Main Services: ['temporary shelter', 'safe housing', 'short-term housing']
# Other Services: ['immediate safety', 'meals', 'group therapy', 'individual counseling', 'after school care', 'childcare', 'navigating the system', 'one-on-one support', 'more education', 'interview training', 'resume development']
# Serving: ['all ages', 'female', 'lgbtqia+', 'male', 'transgender or non-binary', 'abuse or neglect survivors', 'domestic violence survivors', 'emergency']
# Phone Number: 866-723-3014
# Location Address: None
# Location url map: None
# {'24_hour': True, 'Monday': None, 'Tuesday': None, 'Wednesday': None, 'Thursday': None, 'Friday': None, 'Saturday': None, 'Sunday': None}
# Eligibility: ['For women experiencing domestic violence in the Philadelphia area.']
# Availability: available
# Description: Women Against Abuse’s two 24-hour emergency safe havens provide free services to survivors of all gender identities and their children who are victims of domestic violence. This program provides:- Up to 90 days of shelter- Case management- Individual & group counseling- Three meals a day- Children's health assessments- Emergency relocation funds (as available)- Adult education & job readiness referrals- After school & summer school programs- On-site child careIf you need emergency housing because of a domestic violence situation, please call the toll-free 24-hour Philadelphia Domestic Violence Hotline (866-723-3014).
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/womenagainstabuse
# Twitter URL: https://www.twitter.com/@WomenAgnstAbuse
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Crisis Care Services
# URL:  https://www.auntbertha.com//covenant-house--philadelphia-pa--crisis-care-services/5925873791401984?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['temporary shelter']
# Other Services: ['temporary shelter', 'meals', 'clothing', 'home goods', 'medical care', 'personal hygiene', 'physical safety', 'advocacy & legal aid']
# Serving: ['teens', 'foster youth', 'homeless']
# Phone Number: 215-951-5411
# Location Address: 31 East Armat Street, Philadelphia, PA 19144
# Location url map: https://www.google.com/maps/?q=31+East+Armat+Street,+Philadelphia,+PA+19144/
# {'24_hour': False, 'Monday': '8:00 AM - 5:00 PM', 'Tuesday': '8:00 AM - 5:00 PM', 'Wednesday': '8:00 AM - 5:00 PM', 'Thursday': '8:00 AM - 5:00 PM', 'Friday': '8:00 AM - 5:00 PM', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves teens experiencing homelessness.']
# Latitude: 40.0356379
# Longitude: -75.1733708
# ZIP Code: 19144
# Availability: available
# Description: Covenant House's Crisis Care Services are short-term programs where a homeless child's most pressing, urgent needs are met immediately. There is no requirement that a young person be referred through an official channel – they can come anytime, day or night.
#
# This program provides:
#
# - Shelter
# - Hot meal
# - Emergency medical care
# - Showers
#
# This program also provides:
#
# - Mental health care
# - Legal assistance
#
# During the intake process, kids share their stories with trained staff so their immediate needs can be identified and then a plan is created for the best way to support them.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/CovenantHouse
# Twitter URL: https://www.twitter.com/@CovenantHouse
# Coverage Area: This program covers residents of the following cities: Anchorage, AK, Anaheim, CA, Hayward, CA, Los Angeles, CA, Oakland, CA, Santa Clara, CA, Washington, DC, Fort Lauderdale, FL, Orlando, FL, Atlanta, GA, Chicago, IL, New Orleans, LA, Detroit, MI, Grand Rapids, MI, Saint Louis, MO, Asbury Park, NJ, Atlantic City, NJ, Elizabeth, NJ, Jersey City, NJ, Montclair, NJ, Newark, NJ, New York, NY, Philadelphia, PA, York, PA and Houston, TX.
# ***************************************************************************
# Service name:  Emergency Shelter
# URL:  https://www.auntbertha.com//help-usa-pennsylvania--philadelphia-pa--emergency-shelter/5398794886447104?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['temporary shelter', 'skilled nursing', 'prevent & treat', 'navigating the system', 'help find work']
# Other Services: None
# Serving: ['all ages', 'individuals', 'families', 'homeless', 'near homeless', 'low-income', 'abuse or neglect survivors', 'domestic violence survivors']
# No phone number found.
# Location Address: 4910 Wyalusing Avenue, Philadelphia, PA 19131
# Location url map: https://www.google.com/maps/?q=4910+Wyalusing+Avenue,+Philadelphia,+PA+19131/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['For individuals facing homelessness in the Philadelphia area.']
# Latitude: 39.9699305
# Longitude: -75.2192177
# ZIP Code: 19131
# Availability: available
# Description: HELP USA is there for those who find themselves suddenly homeless, and they provide them with safe, temporary shelter and the support they need to get back on their feet. They believe in a different kind of homeless shelter – one that is respectful, supportive, and treats each resident as a unique individual.This program provides:- Temporary shelter- Day care and afterschool care- Physical and mental healthcare- Navigating the system- Help find work
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/helpusa
# Twitter URL: https://www.twitter.com/@HelpUSA
# Coverage Area: This program covers residents of the following counties: Bucks County, PA, Delaware County, PA, Montgomery County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Emergency Shelter
# URL:  https://www.auntbertha.com//gaudenzia--philadelphia-pa--emergency-shelter/6571638428270592?postal=19131
# Reviewed on: 11/13/2024
# Main Services: ['temporary shelter']
# Other Services: None
# Serving: ['adults 18+', 'female', 'male', 'individuals', 'homeless', 'emergency']
# Phone Number: 833-976-4357
# Location Address: 111 North 49th Street, Philadelphia, PA 19139
# Location url map: https://www.google.com/maps/?q=111+North+49th+Street,+Philadelphia,+PA+19139/
# {'24_hour': True, 'Monday': None, 'Tuesday': None, 'Wednesday': None, 'Thursday': None, 'Friday': None, 'Saturday': None, 'Sunday': None}
# Eligibility: []
# Latitude: 39.9619265
# Longitude: -75.2180052
# ZIP Code: 19139
# Availability: available
# Description: Gaudenzia provides temporary shelter and services to meet basic needs when individuals fall on hard times and have nowhere left to go.This program provides:- Temporary shelterThe shelter provides the following additional services: - Meals- Showers
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/gaudenziaorg/
# Twitter URL: https://www.twitter.com/@Gaudenzia
# Coverage Area: This program covers residents of the following cities: Washington, DC, Claymont, DE and Philadelphia, PA.
# ***************************************************************************
# Service name:  Emergency Shelter
# URL:  https://www.auntbertha.com//families-forward--philadelphia-pa--emergency-shelter/6206753615380480?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['temporary shelter']
# Other Services: ['meals', 'daily life skills', 'parenting education', 'financial education', 'navigating the system', 'skills & training', 'computer class']
# Serving: ['all ages', 'individuals', 'families', 'homeless']
# No phone number found.
# Location Address: 111 North 49th Street, Philadelphia, PA 19139
# Location url map: https://www.google.com/maps/?q=111+North+49th+Street,+Philadelphia,+PA+19139/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['All families must be referred to us through the City of Philadelphias Office of Supportive Housing central intake.']
# Latitude: 39.9617037
# Longitude: -75.2184789
# ZIP Code: 19139
# Availability: available
# Description: Families Forward Philadelphia offers an emergency family shelter, for families in need, that has 65 individual rooms. While obtaining housing is their top priority, they also encourage saving money – working with families to dedicate funds to rent, furnishings and day-to-day living expenses once they leave the shelter.This program provides:- A warm, safe environment- Nutritious meals- Case managementAdditionally throughout the day, workshops are available to prepare families for independent living, including parenting classes, life skills development, computer classes, money management classes, and much more.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/FFPhiladelphia/
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Comprehensive Shelters
# URL:  https://www.auntbertha.com//salvation-army-eastern-pennsylvania-%2526-delaware--philadelphia-pa--comprehensive-shelters/5929367212130304?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['temporary shelter']
# Other Services: ['meals', 'community support services', 'spiritual support']
# Serving: ['all ages', 'children', 'individuals', 'families', 'single parent', 'homeless', 'parents']
# Phone Number: 215-474-1010
# Location Address: 5501 Market Street, Philadelphia, PA 19139
# Location url map: https://www.google.com/maps/?q=5501+Market+Street,+Philadelphia,+PA+19139/
# {'24_hour': False, 'Monday': '6:00 AM - 1:00 PM  PST', 'Tuesday': '6:00 AM - 1:00 PM  PST', 'Wednesday': '6:00 AM - 1:00 PM  PST', 'Thursday': '6:00 AM - 1:00 PM  PST', 'Friday': '6:00 AM - 1:00 PM  PST', 'Saturday': '6:00 AM - 1:00 PM  PST', 'Sunday': '6:00 AM - 1:00 PM  PST'}
# Eligibility: ['This program serves homeless individuals and families.']
# Latitude: 39.9610016
# Longitude: -75.2312927
# ZIP Code: 19139
# Availability: available
# Description: Salvation Army shelters welcome all homeless who come to their door. Comprehensive services are available to single-parent families, single women, single men, married couples, children awaiting placement in a foster home, and dual-parent families.This program provides:- Temporary shelter These shelters offer spiritual and physical care, food, and shelter to people in need. They attend the total needs of the individual and are meant to be a kind resting place to help these individuals get back on their feet.
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Kent County, DE, New Castle County, DE, Berks County, PA, Chester County, PA, Lebanon County, PA, Luzerne County, PA, Monroe County, PA, Montgomery County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Jane Addams Place
# URL:  https://www.auntbertha.com//lutheran-settlement-house--philadelphia-pa--jane-addams-place/5730442313465856?postal=19131
# Reviewed on: 12/17/2024
# Main Services: ['temporary shelter', 'case management']
# Other Services: ['health education', 'parenting education', 'medical care', 'mental health care', 'recreation', 'navigating the system', 'help find housing']
# Serving: ['all ages', 'female', 'families', 'with children', 'homeless', 'mothers']
# Phone Number: 215-387-2587
# Location Address: 1007 West Lehigh Avenue, Philadelphia, PA 19104
# Location url map: https://www.google.com/maps/?q=1007+West+Lehigh+Avenue,+Philadelphia,+PA+19104/
# Hours information not available.
# {'24_hour': False, 'Monday': None, 'Tuesday': None, 'Wednesday': None, 'Thursday': None, 'Friday': None, 'Saturday': None, 'Sunday': None}
# Eligibility: ['Centralized Homeless Intake assessment of eligibility required.']
# Latitude: 39.9935454
# Longitude: -75.1482903
# ZIP Code: 19104
# Availability: full
# Description: Jane Addams Place clients are admitted through Centralized Homeless Intake Services operated by the Office of Supportive Housing at the Appletree Family Center at 1430 Cherry Street, 215-686-7150. You must go through central intake for an initial assessment of your housing needs before placement. If you are currently experiencing homelessness, please visit the intake center.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/pages/Lutheran-Settlement-House/152800584747421
# Twitter URL: https://www.twitter.com/@LSH1902
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Men's Shelter
# URL:  https://www.auntbertha.com//the-veterans-group--philadelphia-pa--men%2527s-shelter/6710596967858176?postal=19131
# Reviewed on: 11/13/2024
# Main Services: ['temporary shelter']
# Other Services: ['meals', 'counseling', 'government benefits', 'help find work', 'more education', 'skills & training', 'computer class', 'resume development']
# Serving: ['adults 18+', 'veterans', 'homeless', 'ptsd']
# Phone Number: 215-222-4379
# Location Address: 3209 Baring St, Philadelphia, PA 19104
# Location url map: https://www.google.com/maps/?q=3209+Baring+St,+Philadelphia,+PA+19104/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program helps people who are older than 17 years old.', 'Must have a referral from your local VA.']
# Latitude: 39.9619069
# Longitude: -75.189052
# ZIP Code: 19104
# Availability: available
# Description: The Veterans Group's Men's Shelter provide shelter for up to 41 men, providing them with a roof over their head, warm meals, and a variety of programs and services.This program provides:- ShelterShelter residents will receive: - Meals- PTSD counseling- Basic skills training
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/search/results.php?q=the%20veterans%20group&init=quick&tas=0.9926988141674462#!/pages/The-Veterans-Group/144681825577008
# Twitter URL: https://www.twitter.com/@veterans_group
# Coverage Area: This program covers residents of the following counties: Bucks County, PA, Chester County, PA, Delaware County, PA, Montgomery County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Human Services
# URL:  https://www.auntbertha.com//african-family-health-organization-%2528afaho%2529--philadelphia-pa--human-services/5355967947210752?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['temporary shelter', 'food pantry', 'mental health care', 'navigating the system', 'case management']
# Other Services: None
# Serving: ['all ages', 'immigrants', 'refugees', 'individuals', 'families']
# Phone Number: 215-546-1232
# Location Address: 2420 South 45th Street, Philadelphia, PA 19143
# Location url map: https://www.google.com/maps/?q=2420+South+45th+Street,+Philadelphia,+PA+19143/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves African and Caribbean immigrants/refugees.']
# Latitude: 39.9454475
# Longitude: -75.2085961
# ZIP Code: 19143
# Availability: available
# Description: AFAHO’s multi-lingual and bi-cultural case managers assist clients in mitigating the myriad of barriers they face in accessing critical health and social services which play a vital role in their successful integration, improved health, and ability to be self-sufficient. This program provides:- Behavioral health - Domestic violence awareness and support- Housing assistance and monthly food assistance- Elders' programming- Individual case management- Family case management
# Languages: ['Arabic', 'English', 'French', 'Kinyarwanda', 'Swahili', 'Yoruba']
# Cost: Free
# Facebook URL: https://www.facebook.com/The-Salvation-Army-Nampa-Idaho-208522825852957/
# Twitter URL: https://www.twitter.com/@AFAHO
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Kailo Haven
# URL:  https://www.auntbertha.com//resources-for-human-development-%2528rhd%2529---pennsylvania--philadelphia-pa--kailo-haven/5552002522939392?postal=19131
# Reviewed on: 12/16/2024
# Main Services: ['temporary shelter', 'short-term housing']
# Other Services: ['meals', 'personal hygiene', 'navigating the system', 'one-on-one support', '12-step']
# Serving: ['adults 18+', 'homeless', 'all mental health', 'substance dependency', 'dual diagnosis']
# Phone Number: 215-225-8645
# Location Address: 2107 West Tioga Street, Philadelphia, PA 19140
# Location url map: https://www.google.com/maps/?q=2107+West+Tioga+Street,+Philadelphia,+PA+19140/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves homeless people.']
# Latitude: 40.007932
# Longitude: -75.1637777
# ZIP Code: 19140
# Availability: available
# Description: Resources for Human Development's Kailo Haven is a safe haven homeless shelter for individuals experiencing chronic homelessness and identified as suffering from some form of co-occuring disorders, including mental health and addiction challenges.This program provides:- Safe environment to live and sleep- Meals and snacks- Bathroom and laundry facilities- 12-step recovering meetings- Emotional Management Courses- Individualized meetings and support to obtain financial and medical benefits- Referral ServicesPlease call The Homeless Outreach Hotline at 215-225-8645.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/kailohaven/
# Twitter URL: None
# Coverage Area: This program covers residents of the following cities: Philadelphia, PA.
# ***************************************************************************
# Service name:  Station House Intake Center Services
# URL:  https://www.auntbertha.com//self%252C-inc.--philadelphia-pa--station-house-intake-center-services/6354456388829184?postal=19131
# Reviewed on: 12/19/2024
# Main Services: ['temporary shelter']
# Other Services: ['case management']
# Serving: ['adults 18+', 'male', 'homeless']
# Phone Number: 215-225-9230
# Location Address: 2601 North Broad Street, Philadelphia, PA 19132
# Location url map: https://www.google.com/maps/?q=2601+North+Broad+Street,+Philadelphia,+PA+19132/
# {'24_hour': False, 'Monday': 'Closed', 'Tuesday': 'Closed', 'Wednesday': 'Closed', 'Thursday': 'Closed', 'Friday': 'Closed', 'Saturday': '2:00 PM - 8:00 PM  PST', 'Sunday': '2:00 PM - 8:00 PM  PST'}
# Eligibility: ['We serve single men experiencing homelessness.']
# Latitude: 39.9923482
# Longitude: -75.1544469
# ZIP Code: 19132
# Availability: available
# Description: Centralized Homeless Intake Services includes an assessment of eligibility and service needs of persons and families presenting for placement into emergency housing. If eligible, persons and families are placed in appropriate emergency housing, boarding homes, or other alternative housing. Services include:- Temporary shelter- Ongoing case management services- Assistance with obtaining transitional and/or permanent housing- Supportive housing for special populations- An optional savings program which allows households to save a part of their income for future housing expensesMental health assessments and referrals to drug/alcohol treatment, health services, children and youth services, legal services and veteran’s services, etc., are provided as needed to clients of the program.- Connecting Services to other community resources- ScreeningIf you are currently experiencing homelessness, please call us during business hours. You must go through central intake for an initial assessment of your housing needs before placement into the homeless housing system.
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Station House Shelter
# URL:  https://www.auntbertha.com//self%252C-inc.--philadelphia-pa--station-house-shelter/6293309907009536?postal=19131
# Reviewed on: 12/19/2024
# Main Services: ['temporary shelter']
# Other Services: ['navigating the system', 'case management', 'one-on-one support']
# Serving: ['seniors', 'adults 18+', 'male', 'homeless', 'emergency']
# Phone Number: 215-225-9230
# Location Address: 2601 North Broad Street, Philadelphia, PA 19132
# Location url map: https://www.google.com/maps/?q=2601+North+Broad+Street,+Philadelphia,+PA+19132/
# {'24_hour': False, 'Monday': '2:00 PM - 8:00 PM  PST', 'Tuesday': '2:00 PM - 8:00 PM  PST', 'Wednesday': '2:00 PM - 8:00 PM  PST', 'Thursday': '2:00 PM - 8:00 PM  PST', 'Friday': '2:00 PM - 8:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves single men in North Philadelphia who are experiencing homelessness.']
# Latitude: 39.9923482
# Longitude: -75.1544469
# ZIP Code: 19132
# Availability: available
# Description: The Station House Shelter is an emergency shelter and after hour intake site providing client service case management, a computer lab, and residential services for 99 men in North Philadelphia. This program provides:- Emergency temporary shelter- Case managementStation House includes an intake assessment of eligibility and service needs of persons and families presenting for placement into emergency housing. You must go through a central intake assessment before placement into the homeless housing system. Intake hours for our emergency shelter occur after 5pm.
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Red Shield Family Residence
# URL:  https://www.auntbertha.com//the-salvation-army---greater-philadelphia--philadelphia-pa--red-shield-family-residence/6004150434004992?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['temporary shelter', 'case management']
# Other Services: None
# Serving: ['adults 18+', 'individuals', 'families', 'with children', 'homeless']
# Phone Number: 215-787-2887
# Location Address: 715 North Broad Street, Philadelphia, PA 19123
# Location url map: https://www.google.com/maps/?q=715+North+Broad+Street,+Philadelphia,+PA+19123/
# {'24_hour': False, 'Monday': '2:00 PM - 8:00 PM  PST', 'Tuesday': '2:00 PM - 8:00 PM  PST', 'Wednesday': '2:00 PM - 8:00 PM  PST', 'Thursday': '2:00 PM - 8:00 PM  PST', 'Friday': '2:00 PM - 8:00 PM  PST', 'Saturday': '2:00 PM - 8:00 PM  PST', 'Sunday': '2:00 PM - 8:00 PM  PST'}
# Eligibility: ['Serves families seeking emergency housing.']
# Latitude: 39.9676669
# Longitude: -75.1598736
# ZIP Code: 19123
# Availability: available
# Description: Centralized Homeless Intake Services includes an assessment of eligibility and service needs of persons and families presenting for placement into emergency housing. If eligible, persons and families are placed in appropriate emergency housing, boarding homes, or other alternative housing. Mental health assessments and referrals to drug/alcohol treatment, health services, children and youth services, legal services and veteran’s services, etc., are provided as needed.This program provides:- Temporary shelter- Ongoing case management services- Assistance with obtaining transitional and/or permanent housing- Supportive housing for special populations- An optional savings program which allows households to save a part of their income for future housing expensesIf you are currently experiencing homelessness, please call during business hours. You must go through central intake for an initial assessment of your housing needs before placement into the homeless housing system.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/SalArmyPhilly
# Twitter URL: https://www.twitter.com/@SalArmyPhilly
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Emergency Disaster Services
# URL:  https://www.auntbertha.com//salvation-army-eastern-pennsylvania-%2526-delaware--philadelphia-pa--emergency-disaster-services/5161629360586752?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['disaster response', 'emergency food', 'temporary shelter', 'clothing', 'spiritual support']
# Other Services: None
# Serving: ['all ages', 'natural disaster survivors', 'emergency', 'individuals', 'families']
# No phone number found.
# Location Address: None
# Location url map: None
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: []
# Availability: available
# Description: When disaster strikes, The Salvation Army is often among the first on the scene. In disaster relief operation, The Salvation Army's first aim is to meet the basic needs of those affected – both survivors and first responders.This program provides:- Food- Disaster shelter- Financial assistance- Spiritual care- Emotional carePlease call this provider for more information.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/SalArmyEDS
# Twitter URL: https://www.twitter.com/@SalArmyEDS
# Coverage Area: This program covers residents of the following counties: Adams County, PA, Berks County, PA, Bradford County, PA, Bucks County, PA, Carbon County, PA, Centre County, PA, Chester County, PA, Clinton County, PA, Columbia County, PA, Cumberland County, PA, Dauphin County, PA, Delaware County, PA, Franklin County, PA, Juniata County, PA, Lackawanna County, PA, Lancaster County, PA, Lebanon County, PA, Lehigh County, PA, Luzerne County, PA, Lycoming County, PA, Mifflin County, PA, Monroe County, PA, Montgomery County, PA, Montour County, PA, Northampton County, PA, Northumberland County, PA, Perry County, PA, Philadelphia County, PA, Pike County, PA, Potter County, PA, Schuylkill County, PA, Snyder County, PA, Sullivan County, PA, Susquehanna County, PA, Tioga County, PA, Union County, PA, Wayne County, PA, Wyoming County, PA and York County, PA.
# ***************************************************************************
# Service name:  Church-Based Shelters
# URL:  https://www.auntbertha.com//bethesda-project--philadelphia-pa--church-based-shelters/5997720409997312?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['temporary shelter']
# Other Services: ['meals', 'case management', 'one-on-one support']
# Serving: ['all ages', 'homeless', 'emergency']
# No phone number found.
# Location Address: 2212 Spruce Street, Philadelphia, PA 19103
# Location url map: https://www.google.com/maps/?q=2212+Spruce+Street,+Philadelphia,+PA+19103/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves homeless individuals.']
# Latitude: 39.9483974
# Longitude: -75.1783582
# ZIP Code: 19103
# Availability: available
# Description: In partnership with local churches, Bethesda Project provides shelter for men and women, year round and in the winter. This program provides:- Overnight shelterAdditional offerings for shelter recipients include:- Meals- Case management
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/BethesdaProject
# Twitter URL: https://www.twitter.com/@Bethesda_Proj
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Homeless Shelter
# URL:  https://www.auntbertha.com//stenton-family-manor--philadelphia-pa--homeless-shelter/5186727883833344?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['temporary shelter']
# Other Services: ['meals', 'personal hygiene']
# Serving: ['all ages', 'homeless']
# No phone number found.
# Location Address: 1430 Cherry Street, Philadelphia, PA 19102
# Location url map: https://www.google.com/maps/?q=1430+Cherry+Street,+Philadelphia,+PA+19102/
# {'24_hour': False, 'Monday': '4:00 AM - 12:00 PM  PST', 'Tuesday': '4:00 AM - 12:00 PM  PST', 'Wednesday': '4:00 AM - 12:00 PM  PST', 'Thursday': '4:00 AM - 12:00 PM  PST', 'Friday': '4:00 AM - 12:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['For homeless individuals residing in the Philadelphia, PA area.']
# Latitude: 39.9553624
# Longitude: -75.1642513
# ZIP Code: 19102
# Availability: available
# Description: Stenton Family Manor offers a homeless shelter to those in need of a place to stay.This program provides:- Temporary shelter Intake process is done at the Apple Tree Family Center.
# Languages: ['English', 'Haitian']
# Cost: Free
# Facebook URL: https://www.facebook.com/StentonFamilyManor
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Men's Shelter
# URL:  https://www.auntbertha.com//philly-house--philadelphia-pa--men%2527s-shelter/5704371963166720?postal=19131
# Reviewed on: 12/16/2024
# Main Services: ['temporary shelter']
# Other Services: ['meals', 'personal hygiene']
# Serving: ['adults 18+', 'male', 'individuals', 'homeless', 'emergency']
# Phone Number: 215-922-6400
# Location Address: 302 North 13th Street, Philadelphia, PA 19107
# Location url map: https://www.google.com/maps/?q=302+North+13th+Street,+Philadelphia,+PA+19107/
# Unexpected hours format. Ensure that each day has corresponding hours.
# {'24_hour': False, 'Monday': None, 'Tuesday': None, 'Wednesday': None, 'Thursday': None, 'Friday': None, 'Saturday': None, 'Sunday': None}
# Eligibility: ['This program serves single men in North Philadelphia who are experiencing homelessness.']
# Latitude: 39.958175
# Longitude: -75.160376
# ZIP Code: 19107
# Availability: available
# ...
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/MerakeyOrg
# Twitter URL: None
# Coverage Area: This program covers residents of the following counties: Chester County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  RHD Fernwood Program
# URL:  https://www.auntbertha.com//resources-for-human-development-%2528rhd%2529---pennsylvania--philadelphia-pa--rhd-fernwood-program/4670495380209664?postal=19131
# Reviewed on: 12/13/2024
# Main Services: ['temporary shelter']
# Other Services: ['navigating the system']
# Serving: ['all ages', 'male', 'individuals', 'homeless']
# Phone Number: 215-685-8333
# Location Address: 7979 State Rd, Philadelphia, PA 19136
# Location url map: https://www.google.com/maps/?q=7979+State+Rd,+Philadelphia,+PA+19136/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves single males.']
# Latitude: 40.0311934
# Longitude: -75.0218051
# ZIP Code: 19136
# Availability: available
# Description: RHD Fernwood provides emergency housing for single men in Philadelphia referred by Philadelphia’s Office of Homeless Services. Assessments focus on the immediate needs of the individual. Linkages with community services enable individuals to address primary social service and housing needs.This program provides:- Emergency housing
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/ResourcesHD/timeline/
# Twitter URL: https://www.twitter.com/@Resources4HD
# Coverage Area: This program covers residents of the following counties: Philadelphia County, PA.
# ***************************************************************************
# Service name:  Homeless Veterans Initiative
# URL:  https://www.auntbertha.com//disabled-american-veterans-%2528dav%2529--cold-spring-ky--homeless-veterans-initiative/6359041064304640?postal=19131
# Reviewed on: 12/11/2024
# Main Services: ['temporary shelter', 'government benefits']
# Other Services: None
# Serving: ['veterans']
# Phone Number: 877-426-2838
# Location Address: None
# Location url map: None
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Serves homeless veterans.']
# Availability: available
# Description: The DAV Homeless Veterans Initiative, supported by DAV’s Charitable Service Trust and Columbia Trust, promotes the development of supportive housing and necessary services to assist homeless veterans in becoming productive, self-sufficient members of society. Our goal is to establish a partnership between the DAV and Federal, state, county and local governments to develop programs to assist homeless veterans in becoming self-sufficient.
#
# Service:
#
# -counsel individuals on the many VA benefits for which they may be entitled
#
# If you or someone you know is a homeless veteran in need of assistance, please contact us.
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/DAV
# Twitter URL: https://www.twitter.com/@DAVHQ
# Coverage Area: This program covers residents of All US states and territories.
# ***************************************************************************
# Service name:  Metanoia Refuge
# URL:  https://www.auntbertha.com//metanoia%252C-inc.--zachary-la--metanoia-refuge/5811770958675968?postal=19131
# Reviewed on: 12/17/2024
# Main Services: ['temporary shelter', 'immediate safety']
# Other Services: ['addiction & recovery', 'dental care', 'medical care', 'mental health care', 'medications for mental health', 'navigating the system', 'spiritual support', 'alternative education', 'skills & training']
# Serving: ['teens', 'children', 'female', 'pregnant', 'with children', 'trauma survivors', 'abuse or neglect survivors', 'human trafficking survivors']
# No phone number found.
# Location Address: None
# Location url map: None
# {'24_hour': False, 'Monday': '8:00 AM - 5:00 PM', 'Tuesday': '8:00 AM - 5:00 PM', 'Wednesday': '8:00 AM - 5:00 PM', 'Thursday': '8:00 AM - 5:00 PM', 'Friday': '8:00 AM - 5:00 PM', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program serves female adolescent victims of human trafficking.', 'Must not be HIV-positive.', 'This program helps people who are 11 to 17 years old.']
# Availability: available
# Description: Metanoia offers a place of refuge to female adolescent victims of human trafficking, in which to heal physically and mentally. The program provides girls aged 11-17 with mental, physical, and spiritual health, instruction in academics, life skills, and job training. Once girls reach 18, they can decide whether or not they would like to continue on with the program for additional time.This program provides:- Residential recovery housing Additional services include:- Academic assessments and individualized appropriate curriculum- Individual and group therapy (mental health, substance abuse, equine, canine)- Life skills training- Spiritual guidance (religious activities not required)- Community volunteer opportunities- Health care (medical and dental)- Psychiatric assessment and management of medication- Field Trips- Art, sewing, cooking skills, creative writing, dance, sports, and gardening activities- Employment skills introduction and transitional planningCase managers, service providers, legal guardians, and law enforcement referrals may be made on behalf of the youth. Metanoia assessment forms are required to be completed for consideration to the program. Duration of the stay is as long as needed, until age 18 or 21 with extended foster care. Emergency placement is not provided.Clients across the country are offered free transportation to get to the facility.
# Languages: ['English', 'French', 'Italian', 'Malayalam', 'Spanish', 'Tagalog']
# Cost: Free
# Facebook URL: None
# Twitter URL: None
# Coverage Area: This program covers residents of the following states: AK, AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, HI, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV and WY.
# ***************************************************************************
# Service name:  Veterans Emergency and Transitional Housing
# URL:  https://www.auntbertha.com//soldier-on--northampton-ma--veterans-emergency-and-transitional-housing/5179382369353728?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['temporary shelter', 'short-term housing']
# Other Services: ['meals', 'clothing', 'transportation', 'transportation for healthcare', 'addiction & recovery', 'medical care', 'mental health care', 'navigating the system', 'case management', 'one-on-one support', 'peer support']
# Serving: ['adults 18+', 'veterans', 'individuals', 'homeless', 'near homeless', 'all mental health', 'substance dependency', 'dual diagnosis']
# Phone Number: 413-207-7605
# Location Address: None
# Location url map: None
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['This program helps people who are older than 17 years old.', 'This program serves veterans.']
# Latitude: 42.3472145
# Longitude: -72.6859619
# ZIP Code: 1053
# Availability: available
# Description: Soldier On provides veterans who are homeless with emergency and transitional housing. As residents of Soldier On, veterans receive basic needs, such as shelter, food and clothing. This program provides: - Temporary shelter- Transitional housingResidents receive: - Food- Clothing- Case management- Medical and mental health - Substance abuse treatment- Peer support- Transportation to medical appointments, legal appointments, education and employment
# Languages: ['English']
# Cost: Reduced Cost
# Facebook URL: https://www.facebook.com/SoldierOn
# Twitter URL: https://www.twitter.com/@wesoldieron
# Coverage Area: This program covers residents of the following states: MA, NJ, NY and PA.
# ***************************************************************************
# Service name:  Financial Assistance for Military Families
# URL:  https://www.auntbertha.com//american-red-cross--washington-dc--financial-assistance-for-military-families/5931501920976896?postal=19131
# Reviewed on: 12/18/2024
# Main Services: ['emergency payments', 'emergency food', 'temporary shelter', 'burial & funeral help', 'financial assistance']
# Other Services: None
# Serving: ['adults 18+', 'active duty', 'national guard', 'veterans', 'families', 'spouses', 'emergency']
# Phone Number: 877-272-7337
# Location Address: None
# Location url map: None
# {'24_hour': True, 'Monday': None, 'Tuesday': None, 'Wednesday': None, 'Thursday': None, 'Friday': None, 'Saturday': None, 'Sunday': None}
# Eligibility: ['Eligible for financial assistance if you are: An active duty service member OR', 'A member of an activated National Guard or Reserve unit OR', 'An immediate family member of a service member in the above two categories OR', 'A military retiree or spouse/widow(er) of a retiree.']
# Availability: available
# Description: The American Red Cross works in partnership with military aid societies to provide quality, reliable financial assistance to eligible applicants 24/7/365 in times of hardship.This program provides: - Financial assistance for emergency needsAssistance can include funds for emergency travel, burial of a loved one, emergency food and shelter, etc. Red Cross helps to facilitate the application process, the military aid society determines eligibility and the specific financial assistance package that is offered.You can submit a request online or call the American Red Cross Hero Care Center.  When calliing, be sure to have the following information ready to provide the representative:- Legal name- Rank or rating- Social Security number- Date of birth- Branch of service (Army, Navy, Air Force, Marines, Coast Guard)- Military unit address- Information about the deployed unit and home base unit (for deployed service members only)
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/redcross
# Twitter URL: https://www.twitter.com/@redcross
# Coverage Area: This program covers residents of the following states: AK, AR, AZ, CA, CO, CT, DC, DE, FL, GA, HI, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV and WY.
# ***************************************************************************
# Service name:  Arthur Perry Emergency Shelter
# URL:  https://www.auntbertha.com//good-samaritan-services--phoenixville-pa--arthur-perry-emergency-shelter/6291125027733504?postal=19131
# Reviewed on: 12/19/2024
# Main Services: ['temporary shelter', 'short-term housing']
# Other Services: ['clothing', 'personal care items', 'meals']
# Serving: ['adults', 'young adults', 'teens', 'seniors', 'homeless']
# Phone Number: 610-933-9305
# Location Address: 141 High Street, Phoenixville, PA 19460
# Location url map: https://www.google.com/maps/?q=141+High+Street,+Phoenixville,+PA+19460/
# {'24_hour': False, 'Monday': '5:00 AM - 2:00 PM  PST', 'Tuesday': '5:00 AM - 2:00 PM  PST', 'Wednesday': '5:00 AM - 2:00 PM  PST', 'Thursday': '5:00 AM - 2:00 PM  PST', 'Friday': '5:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: []
# Latitude: 40.1385779
# Longitude: -75.5147235
# ZIP Code: 19460
# Availability: available
# Description: Arthur Perry Emergency Shelter is an eight-bed facility that welcomes men experiencing homelessness. The typical stay in one of our emergency shelters is 30 - 60 days, with the exception of our Code Blue and Code Red months when we are accessible for those in need of nightly shelter. This program offers: - Safe, temporary shelter - Three meals a day- Clothing- Toiletries, linens, and towels- Case management
# Languages: ['English']
# Cost: Free
# Facebook URL: None
# Twitter URL: https://www.twitter.com/@goodsamshelter1
# Coverage Area: This program covers residents of the following counties: Bucks County, PA, Chester County, PA, Delaware County, PA, Montgomery County, PA and Philadelphia County, PA.
# ***************************************************************************
# Service name:  Emergency Family Shelter
# URL:  https://www.auntbertha.com//friends-association-for-care-%2526-protection-of-children--west-chester-pa--emergency-family-shelter/5257544872230912?postal=19131
# Reviewed on: 12/15/2024
# Main Services: ['temporary shelter', 'short-term housing']
# Other Services: ['parenting education', 'one-on-one support', 'skills & training']
# Serving: ['children', 'individuals', 'families', 'homeless', 'near homeless', 'low-income', 'emergency', 'criminal justice history']
# Phone Number: 610-431-3598
# Location Address: 113 West Chestnut Street, West Chester, PA 19380
# Location url map: https://www.google.com/maps/?q=113+West+Chestnut+Street,+West+Chester,+PA+19380/
# {'24_hour': False, 'Monday': '5:30 AM - 1:30 PM  PST', 'Tuesday': '5:30 AM - 1:30 PM  PST', 'Wednesday': '5:30 AM - 1:30 PM  PST', 'Thursday': '5:30 AM - 1:30 PM  PST', 'Friday': '5:30 AM - 9:00 AM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['We serve families with children who are facing homelessness.']
# Latitude: 39.9608131
# Longitude: -75.6077206
# ZIP Code: 19380
# Availability: available
# Description: Friends Association For Care & Protection Of Children offers an emergency family shelter program to homeless families with children that combines a private, safe setting and basic necessities with effective, and individualized case management services. Through the case management process, families set goals, work on addressing past issues that can impact their housing, housekeeping skills, parenting techniques and learn how to have a healthy relationship with their landlord.This program provides:- Short-term housing- Parenting education- Skills and training- Case management
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/pages/Friends-Association-for-Care-and-Protection-of-Children/123600383941
# Twitter URL: None
# Coverage Area: This program covers residents of the following states: PA.
# ***************************************************************************
# Service name:  Emergency Food & Shelter Services
# URL:  https://www.auntbertha.com//pathstone--rochester-ny--emergency-food-%2526-shelter-services/5923475565576192?postal=19131
# Reviewed on: 12/17/2024
# Main Services: ['emergency food', 'temporary shelter']
# Other Services: None
# Serving: ['all ages', 'immigrants', 'refugees', 'undocumented', 'low-income', 'emergency']
# Phone Number: 585-340-3300
# Location Address: None
# Location url map: None
# {'24_hour': False, 'Monday': '6:00 AM - 2:00 PM  PST', 'Tuesday': '6:00 AM - 2:00 PM  PST', 'Wednesday': '6:00 AM - 2:00 PM  PST', 'Thursday': '6:00 AM - 2:00 PM  PST', 'Friday': '6:00 AM - 2:00 PM  PST', 'Saturday': 'Closed', 'Sunday': 'Closed'}
# Eligibility: ['Must be a migrant or seasonal farmworker, or other rural disadvantaged person.', 'Must reside in the coverage area.']
# Availability: available
# Description: PathStone provides one-time emergency services for migrant and seasonal farmworkers, and other rural disadvantaged people, who may not be eligible for other emergency services.This program provides: - Emergency food- Emergency shelter
# Languages: ['English']
# Cost: Free
# Facebook URL: https://www.facebook.com/pathstonecorp/
# Twitter URL: https://www.twitter.com/@PathStoneCorp
# Coverage Area: This program covers residents of the following states: NJ, NY, OH, PA and PR.
# ***************************************************************************

# %%
# Save to CSV file 
#"FindHelp_extracted_data_riv_shelter.csv" is the name for the shelter csv for riv
#"FindHelp_extracted_data_riv_food_pantry.csv" is the name for the food pantry csv for riv
#"FindHelp_extracted_data_riv_mental_health.csv" is the name for the food pantry csv for riv
#"FindHelp_extracted_data_downtown_la_food_pantry.csv" is the name for the food pantry csv for downtown la
csv_filename = "Philadelphia(19131-19154)_Temp_Shelter_Chenzi.csv"

with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # The header 
    header = [
        "Service_name",
        "Service_url",
        "Main_Services",
        "Other_Services",
        "Serving",
        "Phone_Number",
        "Website",
        "Location_Address",
        "Location_URL_Map",
        "Eligibility",
        "Availability",
        "Description",
        "Languages",
        "Cost",
        "Google_Review",
        "Facebook_URL",
        "Twitter_URL",
        "Coverage",
        "Latitude",
        "Longitude",
        "Zipcode",
        "24hour",
        "Monday",
        "Tuesday",
        "Wednesday",
        "Thursday",
        "Friday",
        "Saturday",
        "Sunday"
    ]
    csv_writer.writerow(header)
    
    csv_writer.writerows(data)

# %%
#"FindHelp_extracted_data_riv_shelter.csv" is the name for the shelter csv
#"FindHelp_extracted_data_riv_food_pantry.csv" is the name for the food pantry csv
#"FindHelp_extracted_data_riv_mental_health.csv" is the name for the food pantry csv
#"FindHelp_extracted_data_downtown_la_food_pantry.csv"
#"FindHelp_extracted_data_downtown_la_shelter.csv"
#"FindHelp_extracted_data_downtown_la_mental_health.csv"
#"FindHelp_extracted_data_irvine_food_pantry.csv"
#"FindHelp_extracted_data_irvine_shelter.csv"
#"FindHelp_extracted_data_irvine_mental_health.csv"
df = pd.read_csv("Philadelphia(19131-19154)_Temp_Shelter_Chenzi.csv")

#riv_zipcodes = [92501, 92502, 92503, 92504, 92505, 92506, 92507, 92508, 92513, 92514, 92516, 92517, 92521, 92522]

#downtown_la_zipcodes = [90012, 90013, 90014, 90015, 90017, 90021]

#irvine_zipcodes = [92602, 92603, 92604, 92606, 92612, 92614, 92617, 92618, 92620]

Philadelphia_zipcodes = [19131, 19132, 19133, 19134, 19135, 19136, 19137, 19138, 19139, 19140, 19141, 19142, 19143, 19144, 19145, 19146, 19147, 19148, 19149, 19150, 19151, 19152, 19153, 19154]

filtered_df = df[df['Zipcode'].isin(Philadelphia_zipcodes) | (df['Location_Address'].isna() & df['Longitude'].isna() & df['Latitude'].isna())]

filtered_df = filtered_df.drop_duplicates(subset = ['Website', 'Service_name'])

filtered_df.to_csv("Philadelphia(19131-19154)_Temp_Shelter_Chenzi.csv", index=False, encoding='utf-8')

filtered_df
# Out:
#                                   Service_name  \
# 0                               Drop In Center
# 1          Various Community Events & Programs
# 3                           Overnight Services
# 7                              Cooling Centers
# 8                        Emergency Safe Havens
# 9                         Crisis Care Services
# 10                           Emergency Shelter
# 11                           Emergency Shelter
# 12                           Emergency Shelter
# 13                      Comprehensive Shelters
# 16                              Human Services
# 17                                 Kailo Haven
# 18        Station House Intake Center Services
# 19                       Station House Shelter
# 21                 Emergency Disaster Services
# 26                              Youth Services
# 27                          My Brother's House
# 29               Residential Maternity Shelter
# 31                        RHD Fernwood Program
# 32                Homeless Veterans Initiative
# 33                             Metanoia Refuge
# 35  Financial Assistance for Military Families
# 38           Emergency Food & Shelter Services
#
#                                           Service_url  \
# 0   https://www.auntbertha.com//prevention-point-p...
# 1   https://www.auntbertha.com//conquerors-communi...
# 3   https://www.auntbertha.com//horizon-house--phi...
# 7   https://www.auntbertha.com//city-of-philadelph...
# 8   https://www.auntbertha.com//women-against-abus...
# 9   https://www.auntbertha.com//covenant-house--ph...
# 10  https://www.auntbertha.com//help-usa-pennsylva...
# 11  https://www.auntbertha.com//gaudenzia--philade...
# 12  https://www.auntbertha.com//families-forward--...
# 13  https://www.auntbertha.com//salvation-army-eas...
# 16  https://www.auntbertha.com//african-family-hea...
# 17  https://www.auntbertha.com//resources-for-huma...
# 18  https://www.auntbertha.com//self%252C-inc.--ph...
# 19  https://www.auntbertha.com//self%252C-inc.--ph...
# 21  https://www.auntbertha.com//salvation-army-eas...
# 26  https://www.auntbertha.com//covenant-house-pen...
# 27  https://www.auntbertha.com//bethesda-project--...
# 29  https://www.auntbertha.com//mothers%2527-home-...
# 31  https://www.auntbertha.com//resources-for-huma...
# 32  https://www.auntbertha.com//disabled-american-...
# 33  https://www.auntbertha.com//metanoia%252C-inc....
# 35  https://www.auntbertha.com//american-red-cross...
# 38  https://www.auntbertha.com//pathstone--rochest...
#
#                                         Main_Services  \
# 0   ['weather relief', 'meals', 'addiction & recov...
# 1   ['community support services', 'weather relief...
# 3                               ['temporary shelter']
# 7                                  ['weather relief']
# 8   ['temporary shelter', 'safe housing', 'short-t...
# 9                               ['temporary shelter']
# 10  ['temporary shelter', 'skilled nursing', 'prev...
# 11                              ['temporary shelter']
# 12                              ['temporary shelter']
# 13                              ['temporary shelter']
# 16  ['temporary shelter', 'food pantry', 'mental h...
# 17        ['temporary shelter', 'short-term housing']
# 18                              ['temporary shelter']
# 19                              ['temporary shelter']
# 21  ['disaster response', 'emergency food', 'tempo...
# 26  ['temporary shelter', 'residential housing', '...
# 27  ['temporary shelter', 'safe housing', 'mental ...
# 29              ['temporary shelter', 'safe housing']
# 31                              ['temporary shelter']
# 32       ['temporary shelter', 'government benefits']
# 33          ['temporary shelter', 'immediate safety']
# 35  ['emergency payments', 'emergency food', 'temp...
# 38            ['emergency food', 'temporary shelter']
#
#                                        Other_Services  \
# 0                                                 NaN
# 1   ['community support services', 'weather relief...
# 3   ['meals', 'personal hygiene', 'mental health e...
# 7                                                 NaN
# 8   ['immediate safety', 'meals', 'group therapy',...
# 9   ['temporary shelter', 'meals', 'clothing', 'ho...
# 10                                                NaN
# 11                                                NaN
# 12  ['meals', 'daily life skills', 'parenting educ...
# 13  ['meals', 'community support services', 'spiri...
# 16                                                NaN
# 17  ['meals', 'personal hygiene', 'navigating the ...
# 18                                ['case management']
# 19  ['navigating the system', 'case management', '...
# 21                                                NaN
# 26  ['meals', 'medical care', 'counseling', 'finan...
# 27  ['meals', 'navigating the system', 'case manag...
# 29  ['nutrition education', 'help find housing', '...
# 31                          ['navigating the system']
# 32                                                NaN
# 33  ['addiction & recovery', 'dental care', 'medic...
# 35                                                NaN
# 38                                                NaN
#
#                                               Serving       Phone_Number  \
# 0           ['adults 18+', 'individuals', 'families']                NaN
# 1   ['anyone in need', 'all ages', 'adults', 'youn...       215-474-2717
# 3                          ['adults 18+', 'homeless']  215-386-383812603
# 7   ['anyone in need', 'all ages', 'individuals', ...                NaN
# 8   ['all ages', 'female', 'lgbtqia+', 'male', 'tr...       866-723-3014
# 9               ['teens', 'foster youth', 'homeless']       215-951-5411
# 10  ['all ages', 'individuals', 'families', 'homel...                NaN
# 11  ['adults 18+', 'female', 'male', 'individuals'...       833-976-4357
# 12  ['all ages', 'individuals', 'families', 'homel...                NaN
# 13  ['all ages', 'children', 'individuals', 'famil...       215-474-1010
# 16  ['all ages', 'immigrants', 'refugees', 'indivi...       215-546-1232
# 17  ['adults 18+', 'homeless', 'all mental health'...       215-225-8645
# 18                 ['adults 18+', 'male', 'homeless']       215-225-9230
# 19  ['seniors', 'adults 18+', 'male', 'homeless', ...       215-225-9230
# 21  ['all ages', 'natural disaster survivors', 'em...                NaN
# 26  ['young adults', 'teens', 'children', 'homeles...       888-829-1249
# 27  ['all ages', 'male', 'homeless', 'near homeles...       215-985-1600
# 29  ['adults 18+', 'female', 'pregnant', 'homeless...       610-583-4663
# 31    ['all ages', 'male', 'individuals', 'homeless']       215-685-8333
# 32                                       ['veterans']       877-426-2838
# 33  ['teens', 'children', 'female', 'pregnant', 'w...                NaN
# 35  ['adults 18+', 'active duty', 'national guard'...       877-272-7337
# 38  ['all ages', 'immigrants', 'refugees', 'undocu...       585-340-3300
#
#                                               Website  \
# 0          https://ppponline.org/node/158/drop-center
# 1                  https://www.vccphilly.org/ccdc.php
# 3   https://www.hhinc.org/homeless-services-overvi...
# 7   https://www.phila.gov/services/mental-physical...
# 8   https://www.womenagainstabuse.org/services/saf...
# 9   https://www.covenanthouse.org/childrens-charit...
# 10          http://www.helpusa.org/providing-shelter/
# 11  https://www.gaudenzia.org/the-treatment-and-re...
# 12  https://familiesforwardphilly.org/programs/eme...
# 13  https://easternusa.salvationarmy.org/eastern-p...
# 16                   http://afaho.org/human-services/
# 17           https://www.rhd.org/program/kailo-haven/
# 18           https://www.selfincorp.org/station-house
# 19      https://www.selfincorp.org/service-approaches
# 21  https://easternusa.salvationarmy.org/eastern-p...
# 26  https://www.covenanthousepa.org/our-impact/our...
# 27    https://www.bethesdaproject.org/housing-shelter
# 29                           https://mothershome.org/
# 31          https://www.rhd.org/program/rhd-fernwood/
# 32  https://www.dav.org/get-help-now/veteran-topic...
# 33              https://www.metanoia-inc.org/services
# 35  https://www.redcross.org/get-help/military-fam...
# 38       https://pathstone.org/workforce-development/
#
#                                    Location_Address  \
# 0    2915 Kensington Avenue, Philadelphia, PA 19134
# 1        5220 Whitby Avenue, Philadelphia, PA 19143
# 3        5901 Market Street, Philadelphia, PA 19136
# 7                                               NaN
# 8                                               NaN
# 9      31 East Armat Street, Philadelphia, PA 19144
# 10    4910 Wyalusing Avenue, Philadelphia, PA 19131
# 11    111 North 49th Street, Philadelphia, PA 19139
# 12    111 North 49th Street, Philadelphia, PA 19139
# 13       5501 Market Street, Philadelphia, PA 19139
# 16   2420 South 45th Street, Philadelphia, PA 19143
# 17   2107 West Tioga Street, Philadelphia, PA 19140
# 18  2601 North Broad Street, Philadelphia, PA 19132
# 19  2601 North Broad Street, Philadelphia, PA 19132
# 21                                              NaN
# 26       31 East Armat St. , Philadelphia, PA 19144
# 27    609 South 15th Street, Philadelphia, PA 19146
# 29                                              NaN
# 31            7979 State Rd, Philadelphia, PA 19136
# 32                                              NaN
# 33                                              NaN
# 35                                              NaN
# 38                                              NaN
#
#                                      Location_URL_Map  \
# 0   https://www.google.com/maps/?q=2915+Kensington...
# 1   https://www.google.com/maps/?q=5220+Whitby+Ave...
# 3   https://www.google.com/maps/?q=5901+Market+Str...
# 7                                                 NaN
# 8                                                 NaN
# 9   https://www.google.com/maps/?q=31+East+Armat+S...
# 10  https://www.google.com/maps/?q=4910+Wyalusing+...
# 11  https://www.google.com/maps/?q=111+North+49th+...
# 12  https://www.google.com/maps/?q=111+North+49th+...
# 13  https://www.google.com/maps/?q=5501+Market+Str...
# 16  https://www.google.com/maps/?q=2420+South+45th...
# 17  https://www.google.com/maps/?q=2107+West+Tioga...
# 18  https://www.google.com/maps/?q=2601+North+Broa...
# 19  https://www.google.com/maps/?q=2601+North+Broa...
# 21                                                NaN
# 26  https://www.google.com/maps/?q=31+East+Armat+S...
# 27  https://www.google.com/maps/?q=609+South+15th+...
# 29                                                NaN
# 31  https://www.google.com/maps/?q=7979+State+Rd,+...
# 32                                                NaN
# 33                                                NaN
# 35                                                NaN
# 38                                                NaN
#
#                                           Eligibility  ...  Longitude  \
# 0   ['This program serves residents in Philadelphi...  ... -75.119646
# 1                                                  []  ... -75.227304
# 3       ['This program serves homeless individuals.']  ... -75.239132
# 7                 ['Anyone can access this program.']  ...        NaN
# 8   ['For women experiencing domestic violence in ...  ...        NaN
# 9   ['This program serves teens experiencing homel...  ... -75.173371
# 10  ['For individuals facing homelessness in the P...  ... -75.219218
# 11                                                 []  ... -75.218005
# 12  ['All families must be referred to us through ...  ... -75.218479
# 13  ['This program serves homeless individuals and...  ... -75.231293
# 16  ['This program serves African and Caribbean im...  ... -75.208596
# 17           ['This program serves homeless people.']  ... -75.163778
# 18  ['We serve single men experiencing homelessnes...  ... -75.154447
# 19  ['This program serves single men in North Phil...  ... -75.154447
# 21                                                 []  ...        NaN
# 26  ['This program helps people who are younger th...  ... -75.173371
# 27              ['This program serves homeless men.']  ... -75.167141
# 29  ['This program helps people who are older than...  ...        NaN
# 31              ['This program serves single males.']  ... -75.021805
# 32                      ['Serves homeless veterans.']  ...        NaN
# 33  ['This program serves female adolescent victim...  ...        NaN
# 35  ['Eligible for financial assistance if you are...  ...        NaN
# 38  ['Must be a migrant or seasonal farmworker, or...  ...        NaN
#
#     Zipcode 24hour                  Monday                 Tuesday  \
# 0   19134.0  False  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 1   19143.0  False                     NaN                     NaN
# 3   19136.0   True                     NaN                     NaN
# 7       NaN  False       8:00 AM - 5:00 PM       8:00 AM - 5:00 PM
# 8       NaN   True                     NaN                     NaN
# 9   19144.0  False       8:00 AM - 5:00 PM       8:00 AM - 5:00 PM
# 10  19131.0  False  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 11  19139.0   True                     NaN                     NaN
# 12  19139.0  False  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 13  19139.0  False  6:00 AM - 1:00 PM  PST  6:00 AM - 1:00 PM  PST
# 16  19143.0  False  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 17  19140.0  False  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 18  19132.0  False                  Closed                  Closed
# 19  19132.0  False  2:00 PM - 8:00 PM  PST  2:00 PM - 8:00 PM  PST
# 21      NaN  False  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 26  19144.0   True                     NaN                     NaN
# 27  19146.0  False  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 29      NaN  False  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 31  19136.0  False  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 32      NaN  False  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 33      NaN  False       8:00 AM - 5:00 PM       8:00 AM - 5:00 PM
# 35      NaN   True                     NaN                     NaN
# 38      NaN  False  6:00 AM - 2:00 PM  PST  6:00 AM - 2:00 PM  PST
#
#                  Wednesday                Thursday                  Friday  \
# 0   5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 1                      NaN                     NaN                     NaN
# 3                      NaN                     NaN                     NaN
# 7        8:00 AM - 5:00 PM       8:00 AM - 5:00 PM       8:00 AM - 5:00 PM
# 8                      NaN                     NaN                     NaN
# 9        8:00 AM - 5:00 PM       8:00 AM - 5:00 PM       8:00 AM - 5:00 PM
# 10  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 11                     NaN                     NaN                     NaN
# 12  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 13  6:00 AM - 1:00 PM  PST  6:00 AM - 1:00 PM  PST  6:00 AM - 1:00 PM  PST
# 16  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 17  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 18                  Closed                  Closed                  Closed
# 19  2:00 PM - 8:00 PM  PST  2:00 PM - 8:00 PM  PST  2:00 PM - 8:00 PM  PST
# 21  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 26                     NaN                     NaN                     NaN
# 27  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 29  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 31  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 32  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST  5:00 AM - 2:00 PM  PST
# 33       8:00 AM - 5:00 PM       8:00 AM - 5:00 PM       8:00 AM - 5:00 PM
# 35                     NaN                     NaN                     NaN
# 38  6:00 AM - 2:00 PM  PST  6:00 AM - 2:00 PM  PST  6:00 AM - 2:00 PM  PST
#
#                   Saturday                  Sunday
# 0                   Closed                  Closed
# 1                      NaN                     NaN
# 3                      NaN                     NaN
# 7                   Closed                  Closed
# 8                      NaN                     NaN
# 9                   Closed                  Closed
# 10                  Closed                  Closed
# 11                     NaN                     NaN
# 12                  Closed                  Closed
# 13  6:00 AM - 1:00 PM  PST  6:00 AM - 1:00 PM  PST
# 16                  Closed                  Closed
# 17                  Closed                  Closed
# 18  2:00 PM - 8:00 PM  PST  2:00 PM - 8:00 PM  PST
# 19                  Closed                  Closed
# 21                  Closed                  Closed
# 26                     NaN                     NaN
# 27                  Closed                  Closed
# 29                  Closed                  Closed
# 31                  Closed                  Closed
# 32                  Closed                  Closed
# 33                  Closed                  Closed
# 35                     NaN                     NaN
# 38                  Closed                  Closed
#
# [23 rows x 29 columns]
